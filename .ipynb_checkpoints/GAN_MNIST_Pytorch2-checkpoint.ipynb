# %% [markdown]
# # 1. Understanding GAN models basic concepts

# %% [markdown]
# ## 1.1 Check details of GAN_pytorch.py, understand the whole framework.

# %% [markdown]
# ### 1) Dataset: What is dataset being used? How can you load this dataset?
#
# MNIST dataset was used
#
# this line to download the dataset if not found in the director<br>
# train_data = datasets.MNIST(root=data_dir, train=True, transform=transform, download=True)<br><br>
#
# this line to load the dataset<br>
# train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# %% [markdown]
# ### 2) Model: Can you plot/draw the basic architecture in this case?

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread('arch.png'))

# %% [markdown]
# ### 3) Loss: What is loss function in this example?
#
# Binary Cross Entropy Loss function<br>
# criterion = nn.BCELoss().to(device)

# %% [markdown]
# ### 4) Training: How is this network being trained?
#
# GAN training proceeds in alternating periods:<br>
#
# The discriminator trains for one or more epochs.<br>
# The generator trains for one or more epochs.<br>
# Repeat steps 1 and 2 to continue to train the generator and discriminator networks.<br><br>
#
# We keep the generator constant during the discriminator training phase. As discriminator training tries to figure out how to distinguish real data from fake, it has to learn how to recognize the generator's flaws. That's a different problem for a thoroughly trained generator than it is for an untrained generator that produces random output.<br>
#
# Similarly, we keep the discriminator constant during the generator training phase. Otherwise the generator would be trying to hit a moving target and might never converge.

# %% [markdown]
# ### 5) Test: How do you test this model?
# G learns to make data that is indistiguishable from real data to the discriminator.

# %% [markdown]
# ## 1.2

# %%
import os
import pickle
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
class Generator(nn.Module):
    """Image generator
    
    Takes a noise vector as input and syntheses a single channel image accordingly
    """

    def __init__(self, input_dims, output_dims):
        """Init function
        
        Declare the network structure as indicated in CW2 Guidance
        
        Arguments:
            input_dims {int} -- Dimension of input noise vector
            output_dims {int} -- Dimension of the output vector (flatten image)
        """
        super(Generator, self).__init__()
        ###  TODO: Change the architecture and value as CW2 Guidance required
        self.fc0 = nn.Sequential(
            nn.Linear(input_dims, 128), 
            nn.LeakyReLU(0.2))
        
        # output hidden layer
        self.fc1 = nn.Sequential(
            nn.Linear(128, output_dims), 
            nn.Tanh())

    def forward(self, x):
        """Forward function
        
        Arguments:
            x {Tensor} -- a batch of noise vectors in shape (<batch_size>x<input_dims>)
        
        Returns:
            Tensor -- a batch of flatten image in shape (<batch_size>x<output_dims>)
        """
        ###  TODO: modify to be consistent with the network structure
        x = self.fc0(x)
        x = self.fc1(x)
        return x


class Discriminator(nn.Module):
    """Image discriminator
    
    Takes a image as input and predict if it is real from the dataset or fake synthesised by the generator
    """

    def __init__(self, input_dims, output_dims=1):
        """Init function
        
        Declare the discriminator network structure as indicated in CW2 Guidance
        
        Arguments:
            input_dims {int} -- Dimension of the flatten input images
        
        Keyword Arguments:
            output_dims {int} -- Predicted probability (default: {1})
        """
        super(Discriminator, self).__init__()

        ###  TODO: Change the architecture and value as CW2 Guidance required
  
        self.fc0 = nn.Sequential(
            nn.Linear(input_dims, 784),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        self.fc1 = nn.Sequential(
            nn.Linear(784, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        """Forward function
        
        Arguments:
            x {Tensor} -- a batch of 2D image in shape (<batch_size>xHxW)
        
        Returns:
            Tensor -- predicted probabilities (<batch_size>)
        """
        ###  TODO: modify to be consistent with the network structure

        x = self.fc0(x)
        x = self.fc1(x)
        return x


def show_result(G_net, z_, num_epoch, show=False, save=False, path='result.png'):
    """Result visualisation
    
    Show and save the generated figures in the grid fashion
    
    Arguments:
        G_net {[nn.Module]} -- The generator instant
        z_ {[Tensor]} -- Input noise vectors
        num_epoch {[int]} -- Indicate how many epoch has the generator been trained
    
    Keyword Arguments:
        show {bool} -- If to display the images (default: {False})
        save {bool} -- If to store the images (default: {False})
        path {str} -- path to store the images (default: {'result.png'})
    """

    ###  TODO: complete the rest of part
    # hint: use plt.subplots to construct grid
    # hint: use plt.imshow and plt.savefig to display and store the images
    
    

def show_train_hist(hist, show=False, save=False, path='Train_hist.png'):
    """Loss tracker
    
    Plot the losses of generator and discriminator independently to see the trend
    
    Arguments:
        hist {[dict]} -- Tracking variables
    
    Keyword Arguments:
        show {bool} -- If to display the figure (default: {False})
        save {bool} -- If to store the figure (default: {False})
        path {str} -- path to store the figure (default: {'Train_hist.png'})
    """
    x = range(len(hist['D_losses']))

    y1 = hist['D_losses']
    y2 = hist['G_losses']

    plt.plot(x, y1, label='D_loss')
    plt.plot(x, y2, label='G_loss')

    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.legend(loc=4)
    plt.grid(True)
    plt.tight_layout()

    if save:
        plt.savefig(path)

    if show:
        plt.show()
    else:
        plt.close()

        

def create_noise(num, dim):
    """Noise constructor
    
    returns a tensor filled with random numbers from a standard normal distribution
    
    Arguments:
        num {int} -- Number of vectors
        dim {int} -- Dimension of vectors
    
    Returns:
        [Tensor] -- the generated noise vector batch
    """
    return torch.randn(num, dim)

# %%
if __name__ == '__main__':
    # initialise the device for training, if gpu is available, device = 'cuda', else: device = 'cpu'
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    data_dir = './MNIST_data/'
    save_dir = './MNIST_GAN_results/'
    image_save_dir = './MNIST_GAN_results/results'

    # create folder if not exist
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    if not os.path.exists(image_save_dir):
        os.mkdir(image_save_dir)

# %% [markdown]
# ## Changes here to be made

# %% [markdown]
# ## 1.2 Change the learning rate to 0.01 and train for a few epochs to understand how learning rate will influence the model outcome.

# %%
    # training parameters : change here
    batch_size = 100
    learning_rate = 0.01
    epochs = 100

# %%
    # parameters for Models
    image_size = 28
    G_input_dim = 100
    G_output_dim = image_size * image_size
    D_input_dim = image_size * image_size
    D_output_dim = 1
    hidden_size = 32

# %%
    # construct the dataset and data loader
    transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=(0.5,), std=(0.5,))])
    train_data = datasets.MNIST(root=data_dir, train=True, transform=transform, download=True)
    train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# %%
    # declare the generator and discriminator networks    
    G_net = Generator(G_input_dim, G_output_dim).to(device)
    D_net = Discriminator(D_input_dim, D_output_dim).to(device)

    # Binary Cross Entropy Loss function
    criterion = nn.BCELoss().to(device)

    # Initialise the Optimizers
    G_optimizer = torch.optim.Adam(G_net.parameters(), lr=learning_rate)
    D_optimizer = torch.optim.Adam(D_net.parameters(), lr=learning_rate)

    # tracking variables
    train_hist = {}
    train_hist['D_losses'] = []
    train_hist['G_losses'] = []
    train_hist['per_epoch_ptimes'] = []
    train_hist['total_ptime'] = []

    start_time = time.time()
    # training loop
    for epoch in range(epochs):
        G_net.train()
        D_net.train()
        Loss_G = []
        Loss_D = []
        epoch_start_time = time.time()
        for (image, _) in tqdm(train_loader):
            image = image.to(device)
            b_size = len(image)
            # creat real and fake labels
            real_label = torch.ones(b_size, 1).to(device)
            fake_label = torch.zeros(b_size, 1).to(device)

            # generate fake images 
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))
            data_real = image.view(b_size, D_input_dim)

            # --------train the discriminator network----------
            # compute the loss for real and fake images
            output_real = D_net(data_real)
            output_fake = D_net(data_fake)
            loss_real = criterion(output_real, real_label)
            loss_fake = criterion(output_fake, fake_label)
            loss_d = loss_real + loss_fake

            # back propagation
            D_optimizer.zero_grad()
            loss_d.backward()
            D_optimizer.step()

            # -------- train the generator network-----------
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))

            # compute the loss for generator network
            output_fake = D_net(data_fake)
            loss_g = criterion(output_fake, real_label)

            ## back propagation
            G_optimizer.zero_grad()
            loss_g.backward()
            G_optimizer.step()

            ## store the loss of each iter
            Loss_D.append(loss_d.item())
            Loss_G.append(loss_g.item())

        epoch_loss_g = np.mean(Loss_G)  # mean generator loss for the epoch
        epoch_loss_d = np.mean(Loss_D)  # mean discriminator loss for the epoch
        epoch_end_time = time.time()
        per_epoch_ptime = epoch_end_time - epoch_start_time

        print("Epoch %d of %d with %.2f s" % (epoch + 1, epochs, per_epoch_ptime))
        print("Generator loss: %.8f, Discriminator loss: %.8f" % (epoch_loss_g, epoch_loss_d))

        path = image_save_dir + '/MNIST_GAN_' + str(epoch + 1) + '.png'
        show_result(G_net, create_noise(25, 100).to(device), (epoch + 1), save=True, path=path)
        
        # record the loss for every epoch
        train_hist['G_losses'].append(epoch_loss_g)
        train_hist['D_losses'].append(epoch_loss_d)
        train_hist['per_epoch_ptimes'].append(per_epoch_ptime)

    end_time = time.time()
    total_ptime = end_time - start_time
    train_hist['total_ptime'].append(total_ptime)

    print('Avg per epoch ptime: %.2f, total %d epochs ptime: %.2f' % ( np.mean(train_hist['per_epoch_ptimes']), epochs, total_ptime))
    print("Training finish!... save training results")
    with open(save_dir + '/train_hist.pkl', 'wb') as f:
        pickle.dump(train_hist, f)
    show_train_hist(train_hist, save=True, path=save_dir + '/MNIST_GAN_train_hist.png')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 43.65it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.50it/s]
# Epoch 1 of 100 with 13.75 s
# Generator loss: 47.47044597, Discriminator loss: 4.66060167
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.07it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.44it/s]
# Epoch 2 of 100 with 11.31 s
# Generator loss: 33.40720851, Discriminator loss: 0.95894678
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.53it/s]
#   2%|█▎                                                                               | 10/600 [00:00<00:12, 47.21it/s]
# Epoch 3 of 100 with 11.21 s
# Generator loss: 18.08141021, Discriminator loss: 0.53041569
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.47it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.58it/s]
# Epoch 4 of 100 with 11.66 s
# Generator loss: 11.52984997, Discriminator loss: 0.41460939
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 52.88it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 45.99it/s]
# Epoch 5 of 100 with 11.35 s
# Generator loss: 10.56151542, Discriminator loss: 0.71095753
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.92it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.77it/s]
# Epoch 6 of 100 with 11.13 s
# Generator loss: 9.59752702, Discriminator loss: 0.43331558
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.90it/s]
#   2%|█▎                                                                               | 10/600 [00:00<00:12, 48.63it/s]
# Epoch 7 of 100 with 11.13 s
# Generator loss: 10.19534939, Discriminator loss: 0.48076487
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.90it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 49.15it/s]
# Epoch 8 of 100 with 11.13 s
# Generator loss: 10.56301505, Discriminator loss: 0.58886088
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.94it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 49.15it/s]
# Epoch 9 of 100 with 11.13 s
# Generator loss: 11.51476694, Discriminator loss: 0.52667339
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 54.04it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.67it/s]
# Epoch 10 of 100 with 11.11 s
# Generator loss: 12.60054304, Discriminator loss: 0.55253349
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.71it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.42it/s]
# Epoch 11 of 100 with 11.17 s
# Generator loss: 13.92398480, Discriminator loss: 0.50560725
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.78it/s]
#   2%|█▎                                                                               | 10/600 [00:00<00:12, 46.89it/s]
# Epoch 12 of 100 with 11.82 s
# Generator loss: 15.09502351, Discriminator loss: 0.46971692
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.54it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 41.63it/s]
# Epoch 13 of 100 with 12.62 s
# Generator loss: 14.97940273, Discriminator loss: 0.49638425
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.26it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.74it/s]
# Epoch 14 of 100 with 12.43 s
# Generator loss: 16.68144325, Discriminator loss: 0.58299237
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 46.96it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:16, 36.46it/s]
# Epoch 15 of 100 with 12.78 s
# Generator loss: 17.52184048, Discriminator loss: 0.58212245
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 45.87it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 42.55it/s]
# Epoch 16 of 100 with 13.08 s
# Generator loss: 18.10870513, Discriminator loss: 0.55338788
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.31it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.58it/s]
# Epoch 17 of 100 with 12.17 s
# Generator loss: 20.29257113, Discriminator loss: 0.59928046
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.30it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.58it/s]
# Epoch 18 of 100 with 11.70 s
# Generator loss: 21.39044590, Discriminator loss: 0.80372808
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.23it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.75it/s]
# Epoch 19 of 100 with 11.95 s
# Generator loss: 23.14659431, Discriminator loss: 0.71394531
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.53it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 39.79it/s]
# Epoch 20 of 100 with 11.88 s
# Generator loss: 24.36080876, Discriminator loss: 0.59572952
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.20it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.84it/s]
# Epoch 21 of 100 with 12.20 s
# Generator loss: 27.68941433, Discriminator loss: 0.85395775
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 52.15it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.76it/s]
# Epoch 22 of 100 with 11.51 s
# Generator loss: 29.93209857, Discriminator loss: 0.83481373
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.36it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.76it/s]
# Epoch 23 of 100 with 12.41 s
# Generator loss: 34.17452948, Discriminator loss: 1.32005839
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.38it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:15, 37.84it/s]
# Epoch 24 of 100 with 12.40 s
# Generator loss: 35.31646509, Discriminator loss: 0.80385644
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.87it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.38it/s]
# Epoch 25 of 100 with 12.28 s
# Generator loss: 39.54371489, Discriminator loss: 1.35219705
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.97it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 51.43it/s]
# Epoch 26 of 100 with 11.77 s
# Generator loss: 43.98427524, Discriminator loss: 1.81314559
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.18it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.87it/s]
# Epoch 27 of 100 with 11.96 s
# Generator loss: 51.33187064, Discriminator loss: 2.24637808
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 52.34it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 41.43it/s]
# Epoch 28 of 100 with 11.46 s
# Generator loss: 56.81418133, Discriminator loss: 1.93395025
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 44.51it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:15, 38.57it/s]
# Epoch 29 of 100 with 13.48 s
# Generator loss: 63.49630985, Discriminator loss: 2.51001046
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 46.26it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 40.93it/s]
# Epoch 30 of 100 with 12.97 s
# Generator loss: 69.87318176, Discriminator loss: 2.25090721
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.56it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.94it/s]
# Epoch 31 of 100 with 11.64 s
# Generator loss: 75.94191000, Discriminator loss: 5.42259611
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.87it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:16, 35.81it/s]
# Epoch 32 of 100 with 12.28 s
# Generator loss: 80.82584124, Discriminator loss: 6.66463157
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.13it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.60it/s]
# Epoch 33 of 100 with 11.74 s
# Generator loss: 82.79328800, Discriminator loss: 9.74913208
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.21it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.85it/s]
# Epoch 34 of 100 with 11.72 s
# Generator loss: 85.32325302, Discriminator loss: 10.44030544
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 43.09it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.18it/s]
# Epoch 35 of 100 with 13.93 s
# Generator loss: 85.08445330, Discriminator loss: 11.81327126
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.96it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 49.16it/s]
# Epoch 36 of 100 with 12.51 s
# Generator loss: 84.08738304, Discriminator loss: 16.81623814
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.14it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:15, 39.32it/s]
# Epoch 37 of 100 with 12.47 s
# Generator loss: 83.36842597, Discriminator loss: 20.91645123
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.52it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 42.11it/s]
# Epoch 38 of 100 with 12.12 s
# Generator loss: 72.88343374, Discriminator loss: 33.90420853
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.78it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.86it/s]
# Epoch 39 of 100 with 11.82 s
# Generator loss: 57.58714598, Discriminator loss: 51.79995667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.51it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 40.43it/s]
# Epoch 40 of 100 with 11.21 s
# Generator loss: 80.91800323, Discriminator loss: 29.97907029
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.19it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.41it/s]
# Epoch 41 of 100 with 11.72 s
# Generator loss: 82.34062094, Discriminator loss: 26.55591722
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.35it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.96it/s]
# Epoch 42 of 100 with 11.25 s
# Generator loss: 84.01939894, Discriminator loss: 24.41099215
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 52.37it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.89it/s]
# Epoch 43 of 100 with 11.46 s
# Generator loss: 71.84028919, Discriminator loss: 37.75400942
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.95it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.22it/s]
# Epoch 44 of 100 with 11.55 s
# Generator loss: 72.46101423, Discriminator loss: 36.43788926
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.89it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.59it/s]
# Epoch 45 of 100 with 12.53 s
# Generator loss: 39.92260001, Discriminator loss: 66.11605462
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.54it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:15, 39.31it/s]
# Epoch 46 of 100 with 12.36 s
# Generator loss: 0.07200365, Discriminator loss: 99.89666845
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.58it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 41.65it/s]
# Epoch 47 of 100 with 12.35 s
# Generator loss: 39.25287276, Discriminator loss: 71.45858012
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.13it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 42.85it/s]
# Epoch 48 of 100 with 12.47 s
# Generator loss: 69.33657407, Discriminator loss: 50.24688485
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 46.01it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.01it/s]
# Epoch 49 of 100 with 13.04 s
# Generator loss: 18.83768875, Discriminator loss: 86.25521402
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.90it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.36it/s]
# Epoch 50 of 100 with 12.53 s
# Generator loss: 0.14190526, Discriminator loss: 99.87166667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 45.96it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.60it/s]
# Epoch 51 of 100 with 13.06 s
# Generator loss: 0.10219490, Discriminator loss: 99.85833333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.20it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 41.78it/s]
# Epoch 52 of 100 with 11.95 s
# Generator loss: 0.09987220, Discriminator loss: 99.90333333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.73it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.68it/s]
# Epoch 53 of 100 with 12.07 s
# Generator loss: 0.06324326, Discriminator loss: 99.91166681
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 54.53it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 49.15it/s]
# Epoch 54 of 100 with 11.00 s
# Generator loss: 0.03833333, Discriminator loss: 99.96166668
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.86it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.30it/s]
# Epoch 55 of 100 with 11.14 s
# Generator loss: 0.02333333, Discriminator loss: 99.98333333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 54.58it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.77it/s]
# Epoch 56 of 100 with 10.99 s
# Generator loss: 0.03464127, Discriminator loss: 99.96666667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.01it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:16, 37.14it/s]
# Epoch 57 of 100 with 11.32 s
# Generator loss: 0.02236459, Discriminator loss: 99.96833333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.08it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.77it/s]
# Epoch 58 of 100 with 11.75 s
# Generator loss: 0.03379861, Discriminator loss: 99.97500000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.60it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 42.65it/s]
# Epoch 59 of 100 with 12.60 s
# Generator loss: 0.01333333, Discriminator loss: 99.98333333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 52.56it/s]
#   2%|█▎                                                                               | 10/600 [00:00<00:12, 46.72it/s]
# Epoch 60 of 100 with 11.42 s
# Generator loss: 0.01780310, Discriminator loss: 99.97500000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 52.23it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.01it/s]
# Epoch 61 of 100 with 11.49 s
# Generator loss: 0.01402365, Discriminator loss: 99.98166667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.76it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.37it/s]
# Epoch 62 of 100 with 12.06 s
# Generator loss: 0.07390884, Discriminator loss: 99.93333333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.15it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.17it/s]
# Epoch 63 of 100 with 12.46 s
# Generator loss: 0.96913478, Discriminator loss: 99.21981514
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 52.59it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.58it/s]
# Epoch 64 of 100 with 11.41 s
# Generator loss: 0.18710400, Discriminator loss: 99.80166667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.11it/s]
#   2%|█▎                                                                               | 10/600 [00:00<00:12, 47.34it/s]
# Epoch 65 of 100 with 12.22 s
# Generator loss: 92.83952960, Discriminator loss: 99.91145861
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.52it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.98it/s]
# Epoch 66 of 100 with 12.63 s
# Generator loss: 99.76097088, Discriminator loss: 100.25166667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.35it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 41.10it/s]
# Epoch 67 of 100 with 12.16 s
# Generator loss: 99.80833333, Discriminator loss: 100.21333368
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.69it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.23it/s]
# Epoch 68 of 100 with 12.33 s
# Generator loss: 99.76843995, Discriminator loss: 100.23000000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.03it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.16it/s]
# Epoch 69 of 100 with 12.24 s
# Generator loss: 99.75833333, Discriminator loss: 100.20512513
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.83it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:16, 37.14it/s]
# Epoch 70 of 100 with 12.04 s
# Generator loss: 99.96833333, Discriminator loss: 100.02673921
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 46.86it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.17it/s]
# Epoch 71 of 100 with 12.80 s
# Generator loss: 99.98666667, Discriminator loss: 100.01000000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.27it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.76it/s]
# Epoch 72 of 100 with 11.94 s
# Generator loss: 99.99166667, Discriminator loss: 100.00500000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.00it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:15, 38.01it/s]
# Epoch 73 of 100 with 12.00 s
# Generator loss: 99.99000000, Discriminator loss: 100.00666667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.91it/s]
#   0%|▍                                                                                 | 3/600 [00:00<00:20, 29.82it/s]
# Epoch 74 of 100 with 12.02 s
# Generator loss: 99.99000000, Discriminator loss: 100.00833333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.62it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 41.36it/s]
# Epoch 75 of 100 with 12.34 s
# Generator loss: 99.99000000, Discriminator loss: 100.01166667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.47it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.59it/s]
# Epoch 76 of 100 with 11.89 s
# Generator loss: 99.98500000, Discriminator loss: 100.01000000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.86it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.62it/s]
# Epoch 77 of 100 with 11.57 s
# Generator loss: 99.99333333, Discriminator loss: 100.00333333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.85it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 49.16it/s]
# Epoch 78 of 100 with 12.04 s
# Generator loss: 99.99500000, Discriminator loss: 100.01000000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.51it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.57it/s]
# Epoch 79 of 100 with 11.88 s
# Generator loss: 99.99166667, Discriminator loss: 100.01166667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.35it/s]
#   1%|█                                                                                 | 8/600 [00:00<00:15, 39.02it/s]
# Epoch 80 of 100 with 12.41 s
# Generator loss: 99.99333333, Discriminator loss: 100.00500000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.19it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.22it/s]
# Epoch 81 of 100 with 12.45 s
# Generator loss: 99.99000000, Discriminator loss: 100.00666667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 53.12it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.14it/s]
# Epoch 82 of 100 with 11.30 s
# Generator loss: 99.99228518, Discriminator loss: 100.01000000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 45.62it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.49it/s]
# Epoch 83 of 100 with 13.15 s
# Generator loss: 99.98833333, Discriminator loss: 100.00333333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.03it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.98it/s]
# Epoch 84 of 100 with 12.76 s
# Generator loss: 99.98666667, Discriminator loss: 100.01333333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.12it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:15, 39.42it/s]
# Epoch 85 of 100 with 12.47 s
# Generator loss: 99.99166667, Discriminator loss: 100.00833333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.70it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 42.49it/s]
# Epoch 86 of 100 with 12.07 s
# Generator loss: 99.99000000, Discriminator loss: 100.01000000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.24it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.41it/s]
# Epoch 87 of 100 with 12.19 s
# Generator loss: 99.99333333, Discriminator loss: 100.01166667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 52.52it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.42it/s]
# Epoch 88 of 100 with 11.42 s
# Generator loss: 99.98333333, Discriminator loss: 100.01000000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.99it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.56it/s]
# Epoch 89 of 100 with 11.77 s
# Generator loss: 99.98866793, Discriminator loss: 100.00833333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.03it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.17it/s]
# Epoch 90 of 100 with 11.76 s
# Generator loss: 98.32395262, Discriminator loss: 101.64000000
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.63it/s]
#   1%|▌                                                                                 | 4/600 [00:00<00:15, 39.71it/s]
# Epoch 91 of 100 with 12.09 s
# Generator loss: 99.28603489, Discriminator loss: 100.71502616
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.84it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.17it/s]
# Epoch 92 of 100 with 11.80 s
# Generator loss: 99.66552650, Discriminator loss: 100.33017604
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.35it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 44.38it/s]
# Epoch 93 of 100 with 12.41 s
# Generator loss: 99.93941119, Discriminator loss: 100.06333333
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.59it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.74it/s]
# Epoch 94 of 100 with 12.10 s
# Generator loss: 99.75598736, Discriminator loss: 100.25189575
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.63it/s]
#   2%|█▎                                                                               | 10/600 [00:00<00:12, 46.98it/s]
# Epoch 95 of 100 with 11.62 s
# Generator loss: 99.71571006, Discriminator loss: 100.24691928
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.77it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.77it/s]
# Epoch 96 of 100 with 12.06 s
# Generator loss: 99.97333333, Discriminator loss: 100.02184668
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 50.67it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.67it/s]
# Epoch 97 of 100 with 11.84 s
# Generator loss: 99.97500003, Discriminator loss: 100.02166667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 49.43it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.57it/s]
# Epoch 98 of 100 with 12.14 s
# Generator loss: 99.98905609, Discriminator loss: 100.00679270
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.28it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:14, 41.78it/s]
# Epoch 99 of 100 with 12.69 s
# Generator loss: 99.98852428, Discriminator loss: 100.02191406
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 51.38it/s]
# Epoch 100 of 100 with 11.68 s
# Generator loss: 99.99666667, Discriminator loss: 100.00504420
# Avg per epoch ptime: 12.03, total 100 epochs ptime: 1202.72
# Training finish!... save training results

# %% [markdown]
# As we incresed the lr rate we noticed that generator loss remained high after a little drop and did not go down to the desired region of around 2<br>
# what happend can indicate to a mode collapse and the training failed

# %% [markdown]
# ## 1.3 Change the batch size to 256, and discuss how the batch size influence the model performance regarding its training speed and test accuracy.

# %%
    # training parameters : change here
    batch_size = 256
    learning_rate = 0.0002
    epochs = 100

# %%
    # parameters for Models
    image_size = 28
    G_input_dim = 100
    G_output_dim = image_size * image_size
    D_input_dim = image_size * image_size
    D_output_dim = 1
    hidden_size = 32

# %%
    # construct the dataset and data loader
    transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=(0.5,), std=(0.5,))])
    train_data = datasets.MNIST(root=data_dir, train=True, transform=transform, download=True)
    train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# %%
    # declare the generator and discriminator networks    
    G_net = Generator(G_input_dim, G_output_dim).to(device)
    D_net = Discriminator(D_input_dim, D_output_dim).to(device)

    # Binary Cross Entropy Loss function
    criterion = nn.BCELoss().to(device)

    # Initialise the Optimizers
    G_optimizer = torch.optim.Adam(G_net.parameters(), lr=learning_rate)
    D_optimizer = torch.optim.Adam(D_net.parameters(), lr=learning_rate)

    # tracking variables
    train_hist = {}
    train_hist['D_losses'] = []
    train_hist['G_losses'] = []
    train_hist['per_epoch_ptimes'] = []
    train_hist['total_ptime'] = []

    start_time = time.time()
    # training loop
    for epoch in range(epochs):
        G_net.train()
        D_net.train()
        Loss_G = []
        Loss_D = []
        epoch_start_time = time.time()
        for (image, _) in tqdm(train_loader):
            image = image.to(device)
            b_size = len(image)
            # creat real and fake labels
            real_label = torch.ones(b_size, 1).to(device)
            fake_label = torch.zeros(b_size, 1).to(device)

            # generate fake images 
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))
            data_real = image.view(b_size, D_input_dim)

            # --------train the discriminator network----------
            # compute the loss for real and fake images
            output_real = D_net(data_real)
            output_fake = D_net(data_fake)
            loss_real = criterion(output_real, real_label)
            loss_fake = criterion(output_fake, fake_label)
            loss_d = loss_real + loss_fake

            # back propagation
            D_optimizer.zero_grad()
            loss_d.backward()
            D_optimizer.step()

            # -------- train the generator network-----------
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))

            # compute the loss for generator network
            output_fake = D_net(data_fake)
            loss_g = criterion(output_fake, real_label)

            ## back propagation
            G_optimizer.zero_grad()
            loss_g.backward()
            G_optimizer.step()

            ## store the loss of each iter
            Loss_D.append(loss_d.item())
            Loss_G.append(loss_g.item())

        epoch_loss_g = np.mean(Loss_G)  # mean generator loss for the epoch
        epoch_loss_d = np.mean(Loss_D)  # mean discriminator loss for the epoch
        epoch_end_time = time.time()
        per_epoch_ptime = epoch_end_time - epoch_start_time

        print("Epoch %d of %d with %.2f s" % (epoch + 1, epochs, per_epoch_ptime))
        print("Generator loss: %.8f, Discriminator loss: %.8f" % (epoch_loss_g, epoch_loss_d))

        path = image_save_dir + '/MNIST_GAN_' + str(epoch + 1) + '.png'
        show_result(G_net, create_noise(25, 100).to(device), (epoch + 1), save=True, path=path)
        
        # record the loss for every epoch
        train_hist['G_losses'].append(epoch_loss_g)
        train_hist['D_losses'].append(epoch_loss_d)
        train_hist['per_epoch_ptimes'].append(per_epoch_ptime)

    end_time = time.time()
    total_ptime = end_time - start_time
    train_hist['total_ptime'].append(total_ptime)

    print('Avg per epoch ptime: %.2f, total %d epochs ptime: %.2f' % ( np.mean(train_hist['per_epoch_ptimes']), epochs, total_ptime))
    print("Training finish!... save training results")
    with open(save_dir + '/train_hist.pkl', 'wb') as f:
        pickle.dump(train_hist, f)
    show_train_hist(train_hist, save=True, path=save_dir + '/MNIST_GAN_train_hist.png')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 23.33it/s]
#   1%|▋                                                                                 | 2/235 [00:00<00:12, 18.20it/s]
# Epoch 1 of 100 with 10.08 s
# Generator loss: 1.40977258, Discriminator loss: 0.49126936
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 23.31it/s]
#   1%|▋                                                                                 | 2/235 [00:00<00:13, 17.12it/s]
# Epoch 2 of 100 with 10.08 s
# Generator loss: 1.83418531, Discriminator loss: 0.32108325
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.52it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 21.29it/s]
# Epoch 3 of 100 with 9.99 s
# Generator loss: 2.05971918, Discriminator loss: 0.30464560
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.86it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:11, 20.75it/s]
# Epoch 4 of 100 with 9.85 s
# Generator loss: 2.02759051, Discriminator loss: 0.31476203
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 22.15it/s]
#   1%|▋                                                                                 | 2/235 [00:00<00:13, 17.67it/s]
# Epoch 5 of 100 with 10.61 s
# Generator loss: 2.84448300, Discriminator loss: 0.19012108
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 24.09it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 22.45it/s]
# Epoch 6 of 100 with 9.75 s
# Generator loss: 2.38182912, Discriminator loss: 0.32542821
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.54it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:12, 18.68it/s]
# Epoch 7 of 100 with 9.99 s
# Generator loss: 2.74155047, Discriminator loss: 0.28935413
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 22.93it/s]
#   1%|▋                                                                                 | 2/235 [00:00<00:15, 15.19it/s]
# Epoch 8 of 100 with 10.25 s
# Generator loss: 3.32735689, Discriminator loss: 0.16628879
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 21.69it/s]
#   1%|▋                                                                                 | 2/235 [00:00<00:15, 15.25it/s]
# Epoch 9 of 100 with 10.84 s
# Generator loss: 3.15316657, Discriminator loss: 0.21556414
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 22.79it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 21.87it/s]
# Epoch 10 of 100 with 10.32 s
# Generator loss: 3.17051743, Discriminator loss: 0.21528531
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 23.46it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 21.25it/s]
# Epoch 11 of 100 with 10.02 s
# Generator loss: 3.34828325, Discriminator loss: 0.23405122
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 23.04it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 22.62it/s]
# Epoch 12 of 100 with 10.20 s
# Generator loss: 2.94457609, Discriminator loss: 0.30014250
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.91it/s]
#   1%|▋                                                                                 | 2/235 [00:00<00:17, 13.64it/s]
# Epoch 13 of 100 with 9.83 s
# Generator loss: 2.79521874, Discriminator loss: 0.32393188
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.66it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:11, 19.86it/s]
# Epoch 14 of 100 with 9.93 s
# Generator loss: 2.70391309, Discriminator loss: 0.35959911
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.78it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:11, 20.46it/s]
# Epoch 15 of 100 with 9.88 s
# Generator loss: 2.74839914, Discriminator loss: 0.35897745
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 21.37it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:11, 20.97it/s]
# Epoch 16 of 100 with 11.00 s
# Generator loss: 2.82257865, Discriminator loss: 0.33227999
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 23.34it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:11, 20.61it/s]
# Epoch 17 of 100 with 10.07 s
# Generator loss: 2.80262795, Discriminator loss: 0.34430711
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.73it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 21.64it/s]
# Epoch 18 of 100 with 9.91 s
# Generator loss: 2.82488834, Discriminator loss: 0.36667574
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.83it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:11, 20.89it/s]
# Epoch 19 of 100 with 9.86 s
# Generator loss: 2.86466318, Discriminator loss: 0.39147153
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:10<00:00, 23.49it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:11, 21.04it/s]
# Epoch 20 of 100 with 10.01 s
# Generator loss: 2.73181954, Discriminator loss: 0.44773121
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 24.39it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 21.87it/s]
# Epoch 21 of 100 with 9.64 s
# Generator loss: 2.65144934, Discriminator loss: 0.51155415
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.88it/s]
#   1%|▋                                                                                 | 2/235 [00:00<00:13, 16.72it/s]
# Epoch 22 of 100 with 9.84 s
# Generator loss: 2.71753061, Discriminator loss: 0.47950526
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.91it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 22.79it/s]
# Epoch 23 of 100 with 9.83 s
# Generator loss: 2.80507276, Discriminator loss: 0.44500828
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 23.81it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 22.79it/s]
# Epoch 24 of 100 with 9.87 s
# Generator loss: 2.81052969, Discriminator loss: 0.42498731
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:11<00:00, 19.84it/s]
#   1%|▋                                                                                 | 2/235 [00:00<00:14, 16.57it/s]
# Epoch 25 of 100 with 11.85 s
# Generator loss: 2.93364160, Discriminator loss: 0.39889778
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.68it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:11, 20.89it/s]
# Epoch 26 of 100 with 8.20 s
# Generator loss: 2.99420284, Discriminator loss: 0.40170438
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.98it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 25.71it/s]
# Epoch 27 of 100 with 7.84 s
# Generator loss: 3.00490648, Discriminator loss: 0.43680322
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 30.85it/s]
#   3%|██                                                                                | 6/235 [00:00<00:07, 28.73it/s]
# Epoch 28 of 100 with 7.62 s
# Generator loss: 2.95013980, Discriminator loss: 0.44969210
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 31.06it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 28.64it/s]
# Epoch 29 of 100 with 7.57 s
# Generator loss: 2.97332065, Discriminator loss: 0.44583977
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 30.61it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.68it/s]
# Epoch 30 of 100 with 7.68 s
# Generator loss: 2.97611165, Discriminator loss: 0.44744691
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.79it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.29it/s]
# Epoch 31 of 100 with 7.89 s
# Generator loss: 2.98019174, Discriminator loss: 0.43795153
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 30.53it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 25.07it/s]
# Epoch 32 of 100 with 7.70 s
# Generator loss: 2.96918868, Discriminator loss: 0.43162106
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.34it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.66it/s]
# Epoch 33 of 100 with 8.29 s
# Generator loss: 2.96472152, Discriminator loss: 0.43054568
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.31it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:07, 29.79it/s]
# Epoch 34 of 100 with 8.02 s
# Generator loss: 3.03394716, Discriminator loss: 0.41252632
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 30.92it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.69it/s]
# Epoch 35 of 100 with 7.60 s
# Generator loss: 3.12168651, Discriminator loss: 0.40650381
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.65it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 21.96it/s]
# Epoch 36 of 100 with 7.93 s
# Generator loss: 3.12419505, Discriminator loss: 0.41150541
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.79it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 27.35it/s]
# Epoch 37 of 100 with 8.16 s
# Generator loss: 3.16137128, Discriminator loss: 0.41997969
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 30.34it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.35it/s]
# Epoch 38 of 100 with 7.75 s
# Generator loss: 3.27772433, Discriminator loss: 0.40676699
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.54it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.26it/s]
# Epoch 39 of 100 with 7.96 s
# Generator loss: 3.35328665, Discriminator loss: 0.40048248
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.33it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:07, 29.07it/s]
# Epoch 40 of 100 with 8.30 s
# Generator loss: 3.43895354, Discriminator loss: 0.37287358
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 30.15it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.85it/s]
# Epoch 41 of 100 with 7.80 s
# Generator loss: 3.73263658, Discriminator loss: 0.32910704
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.72it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.63it/s]
# Epoch 42 of 100 with 7.91 s
# Generator loss: 3.93651076, Discriminator loss: 0.31279070
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.37it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 27.86it/s]
# Epoch 43 of 100 with 8.00 s
# Generator loss: 4.16926426, Discriminator loss: 0.27235241
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 31.05it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 28.38it/s]
# Epoch 44 of 100 with 7.57 s
# Generator loss: 4.57739557, Discriminator loss: 0.24772045
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 30.98it/s]
#   3%|██                                                                                | 6/235 [00:00<00:08, 28.15it/s]
# Epoch 45 of 100 with 7.59 s
# Generator loss: 5.15635192, Discriminator loss: 0.20730796
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 30.35it/s]
#   3%|██                                                                                | 6/235 [00:00<00:08, 27.42it/s]
# Epoch 46 of 100 with 7.74 s
# Generator loss: 4.55180137, Discriminator loss: 0.24212006
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.32it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 28.12it/s]
# Epoch 47 of 100 with 8.02 s
# Generator loss: 4.42519172, Discriminator loss: 0.27016582
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.60it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 25.08it/s]
# Epoch 48 of 100 with 7.94 s
# Generator loss: 4.65936654, Discriminator loss: 0.21912314
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.80it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.26it/s]
# Epoch 49 of 100 with 7.89 s
# Generator loss: 4.53510500, Discriminator loss: 0.24848162
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.13it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.86it/s]
# Epoch 50 of 100 with 8.07 s
# Generator loss: 4.35658223, Discriminator loss: 0.27299265
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.53it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.87it/s]
# Epoch 51 of 100 with 8.24 s
# Generator loss: 4.19856371, Discriminator loss: 0.29953698
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.37it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.62it/s]
# Epoch 52 of 100 with 8.28 s
# Generator loss: 4.25833711, Discriminator loss: 0.28860595
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.01it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.15it/s]
# Epoch 53 of 100 with 8.10 s
# Generator loss: 4.28600754, Discriminator loss: 0.28522301
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.63it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.50it/s]
# Epoch 54 of 100 with 7.93 s
# Generator loss: 4.22000937, Discriminator loss: 0.29528638
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 26.98it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 25.38it/s]
# Epoch 55 of 100 with 8.71 s
# Generator loss: 4.01677961, Discriminator loss: 0.30967904
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.18it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.86it/s]
# Epoch 56 of 100 with 8.65 s
# Generator loss: 3.75875465, Discriminator loss: 0.34874293
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.15it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 25.93it/s]
# Epoch 57 of 100 with 8.06 s
# Generator loss: 3.58643693, Discriminator loss: 0.39065975
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.79it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.88it/s]
# Epoch 58 of 100 with 8.46 s
# Generator loss: 3.55269452, Discriminator loss: 0.39722034
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 26.66it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.26it/s]
# Epoch 59 of 100 with 8.81 s
# Generator loss: 3.47196533, Discriminator loss: 0.41243565
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 26.78it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.31it/s]
# Epoch 60 of 100 with 8.78 s
# Generator loss: 3.23939030, Discriminator loss: 0.46964312
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.99it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.86it/s]
# Epoch 61 of 100 with 8.11 s
# Generator loss: 3.30704487, Discriminator loss: 0.46099232
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.88it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.50it/s]
# Epoch 62 of 100 with 8.14 s
# Generator loss: 3.19191066, Discriminator loss: 0.47393182
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.52it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.74it/s]
# Epoch 63 of 100 with 8.54 s
# Generator loss: 3.21422963, Discriminator loss: 0.47632866
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.80it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 27.10it/s]
# Epoch 64 of 100 with 7.89 s
# Generator loss: 3.07656043, Discriminator loss: 0.49386507
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.77it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 25.07it/s]
# Epoch 65 of 100 with 7.89 s
# Generator loss: 3.10261263, Discriminator loss: 0.47212220
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.81it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.96it/s]
# Epoch 66 of 100 with 7.88 s
# Generator loss: 3.11376582, Discriminator loss: 0.48635354
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.85it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.39it/s]
# Epoch 67 of 100 with 7.87 s
# Generator loss: 3.12998616, Discriminator loss: 0.48945810
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.11it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 25.93it/s]
# Epoch 68 of 100 with 8.07 s
# Generator loss: 3.08405972, Discriminator loss: 0.50070264
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.71it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 25.83it/s]
# Epoch 69 of 100 with 7.91 s
# Generator loss: 3.06677462, Discriminator loss: 0.50044381
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.04it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.87it/s]
# Epoch 70 of 100 with 8.09 s
# Generator loss: 3.03537634, Discriminator loss: 0.51026633
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.97it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.94it/s]
# Epoch 71 of 100 with 8.40 s
# Generator loss: 2.96818338, Discriminator loss: 0.51926410
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.70it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.87it/s]
# Epoch 72 of 100 with 8.48 s
# Generator loss: 2.96981852, Discriminator loss: 0.51738795
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:09<00:00, 26.00it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.32it/s]
# Epoch 73 of 100 with 9.04 s
# Generator loss: 2.94814006, Discriminator loss: 0.51925198
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.60it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.46it/s]
# Epoch 74 of 100 with 8.52 s
# Generator loss: 2.91864935, Discriminator loss: 0.51173098
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.48it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.46it/s]
# Epoch 75 of 100 with 7.97 s
# Generator loss: 2.96500311, Discriminator loss: 0.50709361
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.71it/s]
#   0%|▎                                                                                 | 1/235 [00:00<00:27,  8.37it/s]
# Epoch 76 of 100 with 7.91 s
# Generator loss: 3.00081973, Discriminator loss: 0.51080345
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.48it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 25.28it/s]
# Epoch 77 of 100 with 7.97 s
# Generator loss: 2.98073010, Discriminator loss: 0.53335895
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.50it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 25.92it/s]
# Epoch 78 of 100 with 7.97 s
# Generator loss: 2.97232983, Discriminator loss: 0.52259176
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.49it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 25.93it/s]
# Epoch 79 of 100 with 8.55 s
# Generator loss: 2.93737531, Discriminator loss: 0.53752191
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.84it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 25.93it/s]
# Epoch 80 of 100 with 8.15 s
# Generator loss: 2.92372810, Discriminator loss: 0.53344343
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 26.46it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.84it/s]
# Epoch 81 of 100 with 8.88 s
# Generator loss: 2.93173038, Discriminator loss: 0.53628935
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.07it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 25.93it/s]
# Epoch 82 of 100 with 8.68 s
# Generator loss: 2.98096305, Discriminator loss: 0.53271242
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.42it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.28it/s]
# Epoch 83 of 100 with 7.99 s
# Generator loss: 2.87824784, Discriminator loss: 0.55881491
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.05it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.85it/s]
# Epoch 84 of 100 with 8.38 s
# Generator loss: 2.89466681, Discriminator loss: 0.55815627
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.22it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.26it/s]
# Epoch 85 of 100 with 8.04 s
# Generator loss: 2.88698289, Discriminator loss: 0.55420292
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.63it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.87it/s]
# Epoch 86 of 100 with 7.93 s
# Generator loss: 2.88792404, Discriminator loss: 0.55215094
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.61it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 25.82it/s]
# Epoch 87 of 100 with 7.94 s
# Generator loss: 2.90292533, Discriminator loss: 0.54941223
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.53it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 25.07it/s]
# Epoch 88 of 100 with 7.96 s
# Generator loss: 2.90058209, Discriminator loss: 0.54639813
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.60it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 25.82it/s]
# Epoch 89 of 100 with 7.94 s
# Generator loss: 2.91955595, Discriminator loss: 0.53790344
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.72it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 25.28it/s]
# Epoch 90 of 100 with 7.91 s
# Generator loss: 3.03065458, Discriminator loss: 0.52093064
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 29.32it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 25.07it/s]
# Epoch 91 of 100 with 8.02 s
# Generator loss: 3.29550852, Discriminator loss: 0.46108134
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.13it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:10, 22.96it/s]
# Epoch 92 of 100 with 8.36 s
# Generator loss: 3.65264356, Discriminator loss: 0.40948052
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.55it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.39it/s]
# Epoch 93 of 100 with 8.53 s
# Generator loss: 3.97431440, Discriminator loss: 0.34552379
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.89it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 23.32it/s]
# Epoch 94 of 100 with 8.14 s
# Generator loss: 3.92894361, Discriminator loss: 0.34763060
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.67it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:09, 24.45it/s]
# Epoch 95 of 100 with 8.20 s
# Generator loss: 4.07621362, Discriminator loss: 0.34353090
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 28.92it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 27.60it/s]
# Epoch 96 of 100 with 8.13 s
# Generator loss: 4.15244777, Discriminator loss: 0.33010952
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.50it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.62it/s]
# Epoch 97 of 100 with 7.97 s
# Generator loss: 4.14432449, Discriminator loss: 0.32188163
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.81it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.55it/s]
# Epoch 98 of 100 with 7.88 s
# Generator loss: 4.15983813, Discriminator loss: 0.33450402
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:08<00:00, 27.60it/s]
#   1%|█                                                                                 | 3/235 [00:00<00:08, 26.63it/s]
# Epoch 99 of 100 with 8.52 s
# Generator loss: 3.80257137, Discriminator loss: 0.38844047
# 100%|████████████████████████████████████████████████████████████████████████████████| 235/235 [00:07<00:00, 29.88it/s]
# Epoch 100 of 100 with 7.87 s
# Generator loss: 3.70889541, Discriminator loss: 0.40540472
# Avg per epoch ptime: 8.61, total 100 epochs ptime: 861.21
# Training finish!... save training results

# %% [markdown]
# Using batches size of 256, we reaches equivalent loss_g and almost the equivalent for loss_d
# after the same number of training epochs, leading to greater parallelism and shorter training times.

# %% [markdown]
# ## 1.4 Change the training epoch to 200, run it.

# %%
    # training parameters : change here
    batch_size = 100
    learning_rate = 0.0002
    epochs = 200

# %%
    # parameters for Models
    image_size = 28
    G_input_dim = 100
    G_output_dim = image_size * image_size
    D_input_dim = image_size * image_size
    D_output_dim = 1
    hidden_size = 32

# %%
    # construct the dataset and data loader
    transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=(0.5,), std=(0.5,))])
    train_data = datasets.MNIST(root=data_dir, train=True, transform=transform, download=True)
    train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# %%
    # declare the generator and discriminator networks    
    G_net = Generator(G_input_dim, G_output_dim).to(device)
    D_net = Discriminator(D_input_dim, D_output_dim).to(device)

    # Binary Cross Entropy Loss function
    criterion = nn.BCELoss().to(device)

    # Initialise the Optimizers
    G_optimizer = torch.optim.Adam(G_net.parameters(), lr=learning_rate)
    D_optimizer = torch.optim.Adam(D_net.parameters(), lr=learning_rate)

    # tracking variables
    train_hist = {}
    train_hist['D_losses'] = []
    train_hist['G_losses'] = []
    train_hist['per_epoch_ptimes'] = []
    train_hist['total_ptime'] = []

    start_time = time.time()
    # training loop
    for epoch in range(epochs):
        G_net.train()
        D_net.train()
        Loss_G = []
        Loss_D = []
        epoch_start_time = time.time()
        for (image, _) in tqdm(train_loader):
            image = image.to(device)
            b_size = len(image)
            # creat real and fake labels
            real_label = torch.ones(b_size, 1).to(device)
            fake_label = torch.zeros(b_size, 1).to(device)

            # generate fake images 
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))
            data_real = image.view(b_size, D_input_dim)

            # --------train the discriminator network----------
            # compute the loss for real and fake images
            output_real = D_net(data_real)
            output_fake = D_net(data_fake)
            loss_real = criterion(output_real, real_label)
            loss_fake = criterion(output_fake, fake_label)
            loss_d = loss_real + loss_fake

            # back propagation
            D_optimizer.zero_grad()
            loss_d.backward()
            D_optimizer.step()

            # -------- train the generator network-----------
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))

            # compute the loss for generator network
            output_fake = D_net(data_fake)
            loss_g = criterion(output_fake, real_label)

            ## back propagation
            G_optimizer.zero_grad()
            loss_g.backward()
            G_optimizer.step()

            ## store the loss of each iter
            Loss_D.append(loss_d.item())
            Loss_G.append(loss_g.item())

        epoch_loss_g = np.mean(Loss_G)  # mean generator loss for the epoch
        epoch_loss_d = np.mean(Loss_D)  # mean discriminator loss for the epoch
        epoch_end_time = time.time()
        per_epoch_ptime = epoch_end_time - epoch_start_time

        print("Epoch %d of %d with %.2f s" % (epoch + 1, epochs, per_epoch_ptime))
        print("Generator loss: %.8f, Discriminator loss: %.8f" % (epoch_loss_g, epoch_loss_d))

        path = image_save_dir + '/MNIST_GAN_' + str(epoch + 1) + '.png'
        show_result(G_net, create_noise(25, 100).to(device), (epoch + 1), save=True, path=path)
        
        # record the loss for every epoch
        train_hist['G_losses'].append(epoch_loss_g)
        train_hist['D_losses'].append(epoch_loss_d)
        train_hist['per_epoch_ptimes'].append(per_epoch_ptime)

    end_time = time.time()
    total_ptime = end_time - start_time
    train_hist['total_ptime'].append(total_ptime)

    print('Avg per epoch ptime: %.2f, total %d epochs ptime: %.2f' % ( np.mean(train_hist['per_epoch_ptimes']), epochs, total_ptime))
    print("Training finish!... save training results")
    with open(save_dir + '/train_hist.pkl', 'wb') as f:
        pickle.dump(train_hist, f)
    show_train_hist(train_hist, save=True, path=save_dir + '/MNIST_GAN_train_hist.png')
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.44it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.85it/s]
# Epoch 1 of 200 with 9.31 s
# Generator loss: 1.66121156, Discriminator loss: 0.41391625
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.62it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.96it/s]
# Epoch 2 of 200 with 9.74 s
# Generator loss: 2.25272636, Discriminator loss: 0.28838646
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.49it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.76it/s]
# Epoch 3 of 200 with 9.76 s
# Generator loss: 2.31020663, Discriminator loss: 0.37503055
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.68it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 53.31it/s]
# Epoch 4 of 200 with 9.73 s
# Generator loss: 3.05351132, Discriminator loss: 0.22251790
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.80it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.67it/s]
# Epoch 5 of 200 with 10.21 s
# Generator loss: 2.87040813, Discriminator loss: 0.30544983
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 55.82it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 49.15it/s]
# Epoch 6 of 200 with 10.75 s
# Generator loss: 2.58346869, Discriminator loss: 0.41154883
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.95it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.18it/s]
# Epoch 7 of 200 with 10.18 s
# Generator loss: 2.42836788, Discriminator loss: 0.47072880
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.21it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.44it/s]
# Epoch 8 of 200 with 10.14 s
# Generator loss: 2.37973296, Discriminator loss: 0.47883144
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.16it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:12, 49.31it/s]
# Epoch 9 of 200 with 10.14 s
# Generator loss: 2.47737245, Discriminator loss: 0.49084894
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 56.73it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 50.98it/s]
# Epoch 10 of 200 with 10.58 s
# Generator loss: 2.65161619, Discriminator loss: 0.45707752
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.58it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 43.78it/s]
# Epoch 11 of 200 with 10.42 s
# Generator loss: 2.76288304, Discriminator loss: 0.50239179
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.62it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 60.51it/s]
# Epoch 12 of 200 with 9.58 s
# Generator loss: 2.74379585, Discriminator loss: 0.51519817
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.53it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.24it/s]
# Epoch 13 of 200 with 9.60 s
# Generator loss: 2.96714610, Discriminator loss: 0.45454005
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.61it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.03it/s]
# Epoch 14 of 200 with 9.43 s
# Generator loss: 3.38644132, Discriminator loss: 0.38162361
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.35it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.18it/s]
# Epoch 15 of 200 with 9.47 s
# Generator loss: 3.67859324, Discriminator loss: 0.32156747
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.79it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.44it/s]
# Epoch 16 of 200 with 9.87 s
# Generator loss: 3.87780294, Discriminator loss: 0.28995174
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.72it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.02it/s]
# Epoch 17 of 200 with 10.22 s
# Generator loss: 4.29850269, Discriminator loss: 0.23082621
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.20it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 53.14it/s]
# Epoch 18 of 200 with 9.81 s
# Generator loss: 4.88581063, Discriminator loss: 0.17961689
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.12it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.94it/s]
# Epoch 19 of 200 with 10.50 s
# Generator loss: 4.26334587, Discriminator loss: 0.25677036
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.43it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.03it/s]
# Epoch 20 of 200 with 9.46 s
# Generator loss: 4.15403352, Discriminator loss: 0.28728915
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.67it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.01it/s]
# Epoch 21 of 200 with 9.42 s
# Generator loss: 3.70282988, Discriminator loss: 0.35979198
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.92it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.57it/s]
# Epoch 22 of 200 with 9.39 s
# Generator loss: 3.53816988, Discriminator loss: 0.39171627
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.80it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.23it/s]
# Epoch 23 of 200 with 10.20 s
# Generator loss: 3.29095281, Discriminator loss: 0.43639104
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.66it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 56.07it/s]
# Epoch 24 of 200 with 10.23 s
# Generator loss: 3.16744463, Discriminator loss: 0.46772340
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.73it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.72it/s]
# Epoch 25 of 200 with 9.72 s
# Generator loss: 3.03307936, Discriminator loss: 0.51700015
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.36it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.42it/s]
# Epoch 26 of 200 with 10.11 s
# Generator loss: 2.94224001, Discriminator loss: 0.54933751
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.43it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.96it/s]
# Epoch 27 of 200 with 9.61 s
# Generator loss: 2.84741391, Discriminator loss: 0.56074004
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.70it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.70it/s]
# Epoch 28 of 200 with 9.28 s
# Generator loss: 2.88158397, Discriminator loss: 0.54619775
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.90it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.20it/s]
# Epoch 29 of 200 with 9.85 s
# Generator loss: 2.89592520, Discriminator loss: 0.54565947
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.33it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 42.85it/s]
# Epoch 30 of 200 with 10.29 s
# Generator loss: 2.88503173, Discriminator loss: 0.54693977
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.23it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.41it/s]
# Epoch 31 of 200 with 9.97 s
# Generator loss: 2.84561000, Discriminator loss: 0.55892646
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.02it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.84it/s]
# Epoch 32 of 200 with 9.37 s
# Generator loss: 2.85650171, Discriminator loss: 0.56314951
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.76it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 57.10it/s]
# Epoch 33 of 200 with 9.41 s
# Generator loss: 2.80398526, Discriminator loss: 0.57851574
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.93it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 53.73it/s]
# Epoch 34 of 200 with 10.01 s
# Generator loss: 2.83983565, Discriminator loss: 0.56957718
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.45it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.20it/s]
# Epoch 35 of 200 with 10.27 s
# Generator loss: 2.95369572, Discriminator loss: 0.55584613
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.98it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.97it/s]
# Epoch 36 of 200 with 9.53 s
# Generator loss: 3.21873852, Discriminator loss: 0.48169131
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.60it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.69it/s]
# Epoch 37 of 200 with 9.74 s
# Generator loss: 3.75779752, Discriminator loss: 0.39204167
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.00it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.98it/s]
# Epoch 38 of 200 with 9.84 s
# Generator loss: 4.28514369, Discriminator loss: 0.31955136
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.98it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.69it/s]
# Epoch 39 of 200 with 10.00 s
# Generator loss: 4.26405089, Discriminator loss: 0.31161797
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.14it/s]
#   2%|█▊                                                                               | 13/600 [00:00<00:09, 60.05it/s]
# Epoch 40 of 200 with 9.50 s
# Generator loss: 3.86454555, Discriminator loss: 0.38256402
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.02it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.19it/s]
# Epoch 41 of 200 with 9.37 s
# Generator loss: 3.44855449, Discriminator loss: 0.45510039
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.49it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 53.72it/s]
# Epoch 42 of 200 with 9.45 s
# Generator loss: 3.13450988, Discriminator loss: 0.51271478
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.31it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.69it/s]
# Epoch 43 of 200 with 9.95 s
# Generator loss: 3.01540179, Discriminator loss: 0.54622038
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.88it/s]
#   2%|█▍                                                                               | 11/600 [00:00<00:11, 51.87it/s]
# Epoch 44 of 200 with 10.37 s
# Generator loss: 3.01495659, Discriminator loss: 0.54906684
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.41it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.75it/s]
# Epoch 45 of 200 with 10.27 s
# Generator loss: 2.96568338, Discriminator loss: 0.56827761
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.78it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.63it/s]
# Epoch 46 of 200 with 9.71 s
# Generator loss: 2.88179718, Discriminator loss: 0.60298400
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.45it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 47.30it/s]
# Epoch 47 of 200 with 9.93 s
# Generator loss: 2.85307470, Discriminator loss: 0.60679402
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.01it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.76it/s]
# Epoch 48 of 200 with 10.17 s
# Generator loss: 2.85941250, Discriminator loss: 0.61250706
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.57it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 57.08it/s]
# Epoch 49 of 200 with 9.75 s
# Generator loss: 2.80049271, Discriminator loss: 0.62780114
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.56it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.76it/s]
# Epoch 50 of 200 with 9.44 s
# Generator loss: 2.77263650, Discriminator loss: 0.64829419
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.30it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.12it/s]
# Epoch 51 of 200 with 9.95 s
# Generator loss: 2.77411837, Discriminator loss: 0.63942280
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.70it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 59.04it/s]
# Epoch 52 of 200 with 10.05 s
# Generator loss: 2.73599876, Discriminator loss: 0.64544083
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.83it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.69it/s]
# Epoch 53 of 200 with 9.55 s
# Generator loss: 2.71538453, Discriminator loss: 0.65985682
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.72it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.93it/s]
# Epoch 54 of 200 with 10.22 s
# Generator loss: 2.74055115, Discriminator loss: 0.63038886
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.71it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.67it/s]
# Epoch 55 of 200 with 9.72 s
# Generator loss: 2.86699904, Discriminator loss: 0.59516304
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.35it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 53.24it/s]
# Epoch 56 of 200 with 10.46 s
# Generator loss: 2.82631503, Discriminator loss: 0.59556632
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.99it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 45.99it/s]
# Epoch 57 of 200 with 10.00 s
# Generator loss: 2.74163544, Discriminator loss: 0.61304821
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.76it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.11it/s]
# Epoch 58 of 200 with 10.04 s
# Generator loss: 2.71469547, Discriminator loss: 0.62294066
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.60it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 51.86it/s]
# Epoch 59 of 200 with 10.07 s
# Generator loss: 2.72223465, Discriminator loss: 0.62635475
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.38it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.85it/s]
# Epoch 60 of 200 with 10.11 s
# Generator loss: 2.67199350, Discriminator loss: 0.65510578
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.80it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 53.17it/s]
# Epoch 61 of 200 with 9.56 s
# Generator loss: 2.64083352, Discriminator loss: 0.64845244
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.17it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 50.77it/s]
# Epoch 62 of 200 with 9.97 s
# Generator loss: 2.57529716, Discriminator loss: 0.65951621
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.00it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.72it/s]
# Epoch 63 of 200 with 9.68 s
# Generator loss: 2.60175175, Discriminator loss: 0.64476755
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.84it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:09, 59.57it/s]
# Epoch 64 of 200 with 9.55 s
# Generator loss: 2.58609981, Discriminator loss: 0.64959194
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.95it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.85it/s]
# Epoch 65 of 200 with 9.38 s
# Generator loss: 2.61713474, Discriminator loss: 0.64931034
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.38it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 59.30it/s]
# Epoch 66 of 200 with 9.32 s
# Generator loss: 2.66353058, Discriminator loss: 0.63351748
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.33it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.30it/s]
# Epoch 67 of 200 with 9.33 s
# Generator loss: 2.72906699, Discriminator loss: 0.61266683
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.56it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.22it/s]
# Epoch 68 of 200 with 9.30 s
# Generator loss: 2.72537788, Discriminator loss: 0.60634226
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.30it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 62.11it/s]
# Epoch 69 of 200 with 9.33 s
# Generator loss: 2.63990768, Discriminator loss: 0.63277584
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.52it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.76it/s]
# Epoch 70 of 200 with 9.30 s
# Generator loss: 2.62574840, Discriminator loss: 0.63168807
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.07it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:09, 59.41it/s]
# Epoch 71 of 200 with 9.37 s
# Generator loss: 2.55415809, Discriminator loss: 0.65669257
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.53it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.98it/s]
# Epoch 72 of 200 with 9.30 s
# Generator loss: 2.54237955, Discriminator loss: 0.65705289
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.94it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.77it/s]
# Epoch 73 of 200 with 9.38 s
# Generator loss: 2.48985296, Discriminator loss: 0.66757643
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.77it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.20it/s]
# Epoch 74 of 200 with 9.41 s
# Generator loss: 2.49474223, Discriminator loss: 0.67161860
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.24it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 57.02it/s]
# Epoch 75 of 200 with 9.34 s
# Generator loss: 2.52071086, Discriminator loss: 0.65687456
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.23it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.42it/s]
# Epoch 76 of 200 with 9.34 s
# Generator loss: 2.49002465, Discriminator loss: 0.66896609
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.65it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 62.11it/s]
# Epoch 77 of 200 with 9.28 s
# Generator loss: 2.50586950, Discriminator loss: 0.66532472
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.65it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.98it/s]
# Epoch 78 of 200 with 9.28 s
# Generator loss: 2.51564715, Discriminator loss: 0.67432647
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.19it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.23it/s]
# Epoch 79 of 200 with 9.35 s
# Generator loss: 2.52055315, Discriminator loss: 0.66383212
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.32it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.73it/s]
# Epoch 80 of 200 with 9.33 s
# Generator loss: 2.55892893, Discriminator loss: 0.64229256
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.47it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 61.57it/s]
# Epoch 81 of 200 with 9.31 s
# Generator loss: 2.56531512, Discriminator loss: 0.65760482
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.45it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.24it/s]
# Epoch 82 of 200 with 9.31 s
# Generator loss: 2.58091875, Discriminator loss: 0.64962051
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.38it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 61.03it/s]
# Epoch 83 of 200 with 9.32 s
# Generator loss: 2.52385025, Discriminator loss: 0.66209309
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.36it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.14it/s]
# Epoch 84 of 200 with 9.32 s
# Generator loss: 2.47905983, Discriminator loss: 0.67086560
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.84it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.98it/s]
# Epoch 85 of 200 with 9.40 s
# Generator loss: 2.45246211, Discriminator loss: 0.67652535
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.31it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.41it/s]
# Epoch 86 of 200 with 9.33 s
# Generator loss: 2.44525552, Discriminator loss: 0.67002089
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.51it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:09, 58.98it/s]
# Epoch 87 of 200 with 9.45 s
# Generator loss: 2.42861290, Discriminator loss: 0.68560621
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.33it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.01it/s]
# Epoch 88 of 200 with 9.33 s
# Generator loss: 2.42415741, Discriminator loss: 0.69008566
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.58it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.20it/s]
# Epoch 89 of 200 with 9.44 s
# Generator loss: 2.43133059, Discriminator loss: 0.69096733
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.74it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.71it/s]
# Epoch 90 of 200 with 9.72 s
# Generator loss: 2.40011377, Discriminator loss: 0.68261520
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 55.73it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 53.58it/s]
# Epoch 91 of 200 with 10.77 s
# Generator loss: 2.41940662, Discriminator loss: 0.68090230
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 55.60it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 52.77it/s]
# Epoch 92 of 200 with 10.79 s
# Generator loss: 2.43418717, Discriminator loss: 0.68108738
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.28it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.72it/s]
# Epoch 93 of 200 with 9.79 s
# Generator loss: 2.44159566, Discriminator loss: 0.67332329
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.35it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.72it/s]
# Epoch 94 of 200 with 9.62 s
# Generator loss: 2.46180776, Discriminator loss: 0.68143032
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.35it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.76it/s]
# Epoch 95 of 200 with 9.62 s
# Generator loss: 2.50623004, Discriminator loss: 0.66157239
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.78it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.70it/s]
# Epoch 96 of 200 with 10.21 s
# Generator loss: 2.44576518, Discriminator loss: 0.68390656
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.34it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 55.35it/s]
# Epoch 97 of 200 with 9.78 s
# Generator loss: 2.44879167, Discriminator loss: 0.67325410
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.62it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.76it/s]
# Epoch 98 of 200 with 10.41 s
# Generator loss: 2.46124524, Discriminator loss: 0.67074972
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.57it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.30it/s]
# Epoch 99 of 200 with 9.75 s
# Generator loss: 2.44159359, Discriminator loss: 0.67998204
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.65it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 52.31it/s]
# Epoch 100 of 200 with 10.23 s
# Generator loss: 2.44969551, Discriminator loss: 0.69054535
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.24it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.76it/s]
# Epoch 101 of 200 with 9.96 s
# Generator loss: 2.37512807, Discriminator loss: 0.69527129
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.53it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.21it/s]
# Epoch 102 of 200 with 9.75 s
# Generator loss: 2.32984999, Discriminator loss: 0.70136855
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.89it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 58.18it/s]
# Epoch 103 of 200 with 9.54 s
# Generator loss: 2.32662066, Discriminator loss: 0.71511360
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.72it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.41it/s]
# Epoch 104 of 200 with 9.57 s
# Generator loss: 2.32488605, Discriminator loss: 0.70989801
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.01it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 57.46it/s]
# Epoch 105 of 200 with 9.52 s
# Generator loss: 2.30422567, Discriminator loss: 0.72226413
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.58it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.48it/s]
# Epoch 106 of 200 with 9.59 s
# Generator loss: 2.32094332, Discriminator loss: 0.71748304
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.96it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.98it/s]
# Epoch 107 of 200 with 9.53 s
# Generator loss: 2.31605026, Discriminator loss: 0.70217471
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.97it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.59it/s]
# Epoch 108 of 200 with 9.53 s
# Generator loss: 2.31386636, Discriminator loss: 0.71995256
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.25it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.98it/s]
# Epoch 109 of 200 with 9.49 s
# Generator loss: 2.31345949, Discriminator loss: 0.72291912
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.04it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.24it/s]
# Epoch 110 of 200 with 9.52 s
# Generator loss: 2.30301435, Discriminator loss: 0.71328854
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.81it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 59.00it/s]
# Epoch 111 of 200 with 9.55 s
# Generator loss: 2.28380663, Discriminator loss: 0.71736468
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.68it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 56.70it/s]
# Epoch 112 of 200 with 9.57 s
# Generator loss: 2.28071662, Discriminator loss: 0.72268716
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.89it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.84it/s]
# Epoch 113 of 200 with 9.85 s
# Generator loss: 2.26959444, Discriminator loss: 0.72283096
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.70it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.22it/s]
# Epoch 114 of 200 with 9.57 s
# Generator loss: 2.26891933, Discriminator loss: 0.71144597
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.87it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.57it/s]
# Epoch 115 of 200 with 9.54 s
# Generator loss: 2.26139064, Discriminator loss: 0.73000781
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.20it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.34it/s]
# Epoch 116 of 200 with 9.65 s
# Generator loss: 2.25825099, Discriminator loss: 0.73518500
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.09it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.18it/s]
# Epoch 117 of 200 with 9.51 s
# Generator loss: 2.19728160, Discriminator loss: 0.74279396
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.30it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 45.99it/s]
# Epoch 118 of 200 with 9.95 s
# Generator loss: 2.21532221, Discriminator loss: 0.74461685
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.11it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.19it/s]
# Epoch 119 of 200 with 9.82 s
# Generator loss: 2.20920317, Discriminator loss: 0.73957396
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.83it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.30it/s]
# Epoch 120 of 200 with 9.71 s
# Generator loss: 2.19656674, Discriminator loss: 0.74524513
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.60it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.45it/s]
# Epoch 121 of 200 with 9.74 s
# Generator loss: 2.20388204, Discriminator loss: 0.74269260
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.22it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.69it/s]
# Epoch 122 of 200 with 9.64 s
# Generator loss: 2.19702778, Discriminator loss: 0.74068363
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.06it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.58it/s]
# Epoch 123 of 200 with 9.67 s
# Generator loss: 2.17263246, Discriminator loss: 0.74984503
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.08it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 51.42it/s]
# Epoch 124 of 200 with 9.67 s
# Generator loss: 2.15572459, Discriminator loss: 0.75584457
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.87it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 49.07it/s]
# Epoch 125 of 200 with 10.37 s
# Generator loss: 2.14156359, Discriminator loss: 0.75865376
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.58it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 51.20it/s]
# Epoch 126 of 200 with 10.07 s
# Generator loss: 2.17284207, Discriminator loss: 0.74790450
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.64it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.70it/s]
# Epoch 127 of 200 with 9.90 s
# Generator loss: 2.13849903, Discriminator loss: 0.75163408
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.68it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.90it/s]
# Epoch 128 of 200 with 10.23 s
# Generator loss: 2.13757231, Discriminator loss: 0.75099626
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.53it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 59.46it/s]
# Epoch 129 of 200 with 10.43 s
# Generator loss: 2.15277269, Discriminator loss: 0.75593533
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.16it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 59.99it/s]
# Epoch 130 of 200 with 9.65 s
# Generator loss: 2.11904073, Discriminator loss: 0.74910136
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.16it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.86it/s]
# Epoch 131 of 200 with 9.50 s
# Generator loss: 2.14567789, Discriminator loss: 0.76402344
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.82it/s]
#   2%|█▍                                                                               | 11/600 [00:00<00:11, 51.84it/s]
# Epoch 132 of 200 with 10.20 s
# Generator loss: 2.11690274, Discriminator loss: 0.75839993
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.63it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.21it/s]
# Epoch 133 of 200 with 10.24 s
# Generator loss: 2.09653915, Discriminator loss: 0.76639069
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.31it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 56.65it/s]
# Epoch 134 of 200 with 9.95 s
# Generator loss: 2.10425915, Discriminator loss: 0.76444649
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.28it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.30it/s]
# Epoch 135 of 200 with 9.79 s
# Generator loss: 2.10610046, Discriminator loss: 0.75869837
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.74it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.42it/s]
# Epoch 136 of 200 with 9.88 s
# Generator loss: 2.09000994, Discriminator loss: 0.76843540
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.48it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.23it/s]
# Epoch 137 of 200 with 9.45 s
# Generator loss: 2.08682024, Discriminator loss: 0.76587095
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.44it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 55.91it/s]
# Epoch 138 of 200 with 9.46 s
# Generator loss: 2.07286383, Discriminator loss: 0.77570478
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.34it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.19it/s]
# Epoch 139 of 200 with 10.11 s
# Generator loss: 2.06772865, Discriminator loss: 0.77702653
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 54.85it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.21it/s]
# Epoch 140 of 200 with 10.94 s
# Generator loss: 2.06409811, Discriminator loss: 0.77181858
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 55.25it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.20it/s]
# Epoch 141 of 200 with 10.86 s
# Generator loss: 2.06635981, Discriminator loss: 0.77423897
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.14it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.20it/s]
# Epoch 142 of 200 with 9.98 s
# Generator loss: 2.04441847, Discriminator loss: 0.77572639
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.58it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.70it/s]
# Epoch 143 of 200 with 9.59 s
# Generator loss: 2.06381346, Discriminator loss: 0.77678860
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.55it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 61.27it/s]
# Epoch 144 of 200 with 9.59 s
# Generator loss: 2.03679176, Discriminator loss: 0.78021430
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.40it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.92it/s]
# Epoch 145 of 200 with 9.62 s
# Generator loss: 2.04899235, Discriminator loss: 0.77227458
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.82it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 49.15it/s]
# Epoch 146 of 200 with 9.87 s
# Generator loss: 2.04352213, Discriminator loss: 0.77628289
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.57it/s]
# ...
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.29it/s]
# Epoch 152 of 200 with 9.59 s
# Generator loss: 2.02011775, Discriminator loss: 0.78283835
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.99it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:09, 58.86it/s]
# Epoch 153 of 200 with 9.23 s
# Generator loss: 2.01339546, Discriminator loss: 0.78408026
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.97it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 51.86it/s]
# Epoch 154 of 200 with 9.24 s
# Generator loss: 2.00603356, Discriminator loss: 0.78184308
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.08it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.85it/s]
# Epoch 155 of 200 with 9.51 s
# Generator loss: 2.01410255, Discriminator loss: 0.78059886
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 66.08it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.75it/s]
# Epoch 156 of 200 with 9.08 s
# Generator loss: 2.00098932, Discriminator loss: 0.78740667
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 66.03it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 61.05it/s]
# Epoch 157 of 200 with 9.09 s
# Generator loss: 2.00797139, Discriminator loss: 0.79229262
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 66.11it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.69it/s]
# Epoch 158 of 200 with 9.08 s
# Generator loss: 1.99951234, Discriminator loss: 0.78962227
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 65.21it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.23it/s]
# Epoch 159 of 200 with 9.20 s
# Generator loss: 1.98185771, Discriminator loss: 0.79363828
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 66.12it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 62.11it/s]
# Epoch 160 of 200 with 9.08 s
# Generator loss: 2.00543357, Discriminator loss: 0.78534060
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 65.83it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 59.25it/s]
# Epoch 161 of 200 with 9.12 s
# Generator loss: 1.98052910, Discriminator loss: 0.78661989
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 65.06it/s]
#   1%|▉                                                                                 | 7/600 [00:00<00:09, 60.51it/s]
# Epoch 162 of 200 with 9.22 s
# Generator loss: 1.98851980, Discriminator loss: 0.78587431
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.53it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.31it/s]
# Epoch 163 of 200 with 10.08 s
# Generator loss: 1.99651389, Discriminator loss: 0.79112793
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 56.66it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.53it/s]
# Epoch 164 of 200 with 10.59 s
# Generator loss: 1.97739842, Discriminator loss: 0.78739843
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.61it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.89it/s]
# Epoch 165 of 200 with 10.42 s
# Generator loss: 1.96644932, Discriminator loss: 0.78996095
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.29it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.84it/s]
# Epoch 166 of 200 with 9.95 s
# Generator loss: 1.97659688, Discriminator loss: 0.80067677
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.81it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 57.53it/s]
# Epoch 167 of 200 with 9.41 s
# Generator loss: 1.97788674, Discriminator loss: 0.79389741
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.23it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.30it/s]
# Epoch 168 of 200 with 9.49 s
# Generator loss: 1.97323766, Discriminator loss: 0.78992958
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.97it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 58.42it/s]
# Epoch 169 of 200 with 9.84 s
# Generator loss: 1.96404063, Discriminator loss: 0.79830008
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.60it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 57.96it/s]
# Epoch 170 of 200 with 9.90 s
# Generator loss: 1.96202240, Discriminator loss: 0.79575638
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.95it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:13, 45.55it/s]
# Epoch 171 of 200 with 10.01 s
# Generator loss: 1.96028170, Discriminator loss: 0.79534694
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.08it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.85it/s]
# Epoch 172 of 200 with 9.82 s
# Generator loss: 1.95489207, Discriminator loss: 0.79799765
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.42it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.20it/s]
# Epoch 173 of 200 with 9.61 s
# Generator loss: 1.95950127, Discriminator loss: 0.80119036
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.11it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.86it/s]
# Epoch 174 of 200 with 9.82 s
# Generator loss: 1.95063729, Discriminator loss: 0.79515808
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.54it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 49.12it/s]
# Epoch 175 of 200 with 9.91 s
# Generator loss: 1.96331884, Discriminator loss: 0.80193300
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.45it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 58.07it/s]
# Epoch 176 of 200 with 9.76 s
# Generator loss: 1.95245145, Discriminator loss: 0.79942988
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.02it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 55.76it/s]
# Epoch 177 of 200 with 9.52 s
# Generator loss: 1.95235484, Discriminator loss: 0.80030414
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.14it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.19it/s]
# Epoch 178 of 200 with 9.50 s
# Generator loss: 1.94529256, Discriminator loss: 0.79237635
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.50it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 52.77it/s]
# Epoch 179 of 200 with 9.45 s
# Generator loss: 1.94935937, Discriminator loss: 0.80528179
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.42it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 54.71it/s]
# Epoch 180 of 200 with 9.46 s
# Generator loss: 1.93976569, Discriminator loss: 0.79969258
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 59.79it/s]
#   2%|█▍                                                                               | 11/600 [00:00<00:11, 51.04it/s]
# Epoch 181 of 200 with 10.04 s
# Generator loss: 1.93936992, Discriminator loss: 0.80286706
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 56.09it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.71it/s]
# Epoch 182 of 200 with 10.70 s
# Generator loss: 1.94561922, Discriminator loss: 0.79276161
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.65it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 53.00it/s]
# Epoch 183 of 200 with 10.23 s
# Generator loss: 1.94958405, Discriminator loss: 0.80125993
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.43it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.19it/s]
# Epoch 184 of 200 with 9.77 s
# Generator loss: 1.94372519, Discriminator loss: 0.80507731
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.41it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:09, 59.14it/s]
# Epoch 185 of 200 with 9.46 s
# Generator loss: 1.93631143, Discriminator loss: 0.80385113
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 60.56it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:09, 59.86it/s]
# Epoch 186 of 200 with 9.91 s
# Generator loss: 1.93624195, Discriminator loss: 0.79801223
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.51it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 55.44it/s]
# Epoch 187 of 200 with 9.45 s
# Generator loss: 1.94071068, Discriminator loss: 0.80334967
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 64.57it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.74it/s]
# Epoch 188 of 200 with 9.29 s
# Generator loss: 1.93054717, Discriminator loss: 0.80461768
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 65.02it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.76it/s]
# Epoch 189 of 200 with 9.23 s
# Generator loss: 1.91991035, Discriminator loss: 0.80085216
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.78it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 52.77it/s]
# Epoch 190 of 200 with 9.41 s
# Generator loss: 1.93226170, Discriminator loss: 0.79988029
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.16it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.66it/s]
# Epoch 191 of 200 with 9.50 s
# Generator loss: 1.92610389, Discriminator loss: 0.80817214
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.78it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 57.01it/s]
# Epoch 192 of 200 with 9.41 s
# Generator loss: 1.93533263, Discriminator loss: 0.79874819
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 61.01it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.22it/s]
# Epoch 193 of 200 with 9.84 s
# Generator loss: 1.95555287, Discriminator loss: 0.79655552
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.16it/s]
#   2%|█▌                                                                               | 12/600 [00:00<00:10, 58.58it/s]
# Epoch 194 of 200 with 9.50 s
# Generator loss: 1.92467052, Discriminator loss: 0.80858822
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 58.49it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 48.67it/s]
# Epoch 195 of 200 with 10.26 s
# Generator loss: 1.92766606, Discriminator loss: 0.79998581
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.95it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 53.95it/s]
# Epoch 196 of 200 with 10.36 s
# Generator loss: 1.93371514, Discriminator loss: 0.79867193
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:10<00:00, 57.48it/s]
#   1%|▋                                                                                 | 5/600 [00:00<00:12, 46.42it/s]
# Epoch 197 of 200 with 10.44 s
# Generator loss: 1.91852197, Discriminator loss: 0.79957582
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 63.15it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:10, 56.97it/s]
# Epoch 198 of 200 with 9.50 s
# Generator loss: 1.93713774, Discriminator loss: 0.80078398
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:09<00:00, 62.22it/s]
#   1%|▊                                                                                 | 6/600 [00:00<00:11, 50.56it/s]
# Epoch 199 of 200 with 9.65 s
# Generator loss: 1.93163282, Discriminator loss: 0.80723900
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:11<00:00, 54.03it/s]
# Epoch 200 of 200 with 11.11 s
# Generator loss: 1.92899526, Discriminator loss: 0.80617598
# Avg per epoch ptime: 9.76, total 200 epochs ptime: 1951.86
# Training finish!... save training results

# %% [markdown]
# Loss_d has signifantly decreased, loss_g increased a little bit.

# %% [markdown]
# # 2. Generative Adversarial Networks with PyTorch

# %% [markdown]
# ## 2.1 modify architecture

# %%
import os
import pickle
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
class Generator(nn.Module):
    """Image generator
    
    Takes a noise vector as input and syntheses a single channel image accordingly
    """

    def __init__(self, input_dims, output_dims):
        """Init function
        
        Declare the network structure as indicated in CW2 Guidance
        
        Arguments:
            input_dims {int} -- Dimension of input noise vector
            output_dims {int} -- Dimension of the output vector (flatten image)
        """
        super(Generator, self).__init__()
        ###  TODO: Change the architecture and value as CW2 Guidance required

        self.fc1 = nn.Sequential(
            nn.Linear(100, 256), 
            nn.LeakyReLU(0.2)
        )
        
        self.fc2 = nn.Sequential(
            nn.Linear(256, 512), 
            nn.LeakyReLU(0.2)
        )
        
        self.fc3 = nn.Sequential(
            nn.Linear(512, 1024), 
            nn.LeakyReLU(0.2)
        )  
        
        # output hidden layer
        self.fc4 = nn.Sequential(
            nn.Linear(1024, output_dims), 
            nn.Tanh()
        )

    def forward(self, x):
        """Forward function
        
        Arguments:
            x {Tensor} -- a batch of noise vectors in shape (<batch_size>x<input_dims>)
        
        Returns:
            Tensor -- a batch of flatten image in shape (<batch_size>x<output_dims>)
        """
        ###  TODO: modify to be consistent with the network structure

        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x


class Discriminator(nn.Module):
    """Image discriminator
    
    Takes a image as input and predict if it is real from the dataset or fake synthesised by the generator
    """

    def __init__(self, input_dims, output_dims=1):
        """Init function
        
        Declare the discriminator network structure as indicated in CW2 Guidance
        
        Arguments:
            input_dims {int} -- Dimension of the flatten input images
        
        Keyword Arguments:
            output_dims {int} -- Predicted probability (default: {1})
        """
        super(Discriminator, self).__init__()

        ###  TODO: Change the architecture and value as CW2 Guidance required
        
        self.fc1 = nn.Sequential(
            nn.Linear(784, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        
        self.fc2 = nn.Sequential(
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        
        self.fc3 = nn.Sequential(
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        
        self.fc4 = nn.Sequential(
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        """Forward function
        
        Arguments:
            x {Tensor} -- a batch of 2D image in shape (<batch_size>xHxW)
        
        Returns:
            Tensor -- predicted probabilities (<batch_size>)
        """
        ###  TODO: modify to be consistent with the network structure

        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)

        return x

# %%
def show_result(G_net, z_, num_epoch, show=False, save=False, path='result.png'):
    """Result visualisation
    
    Show and save the generated figures in the grid fashion
    
    Arguments:
        G_net {[nn.Module]} -- The generator instant
        z_ {[Tensor]} -- Input noise vectors
        num_epoch {[int]} -- Indicate how many epoch has the generator been trained
    
    Keyword Arguments:
        show {bool} -- If to display the images (default: {False})
        save {bool} -- If to store the images (default: {False})
        path {str} -- path to store the images (default: {'result.png'})
    """

    ###  TODO: complete the rest of part
    # hint: use plt.subplots to construct grid
    # hint: use plt.imshow and plt.savefig to display and store the images
    
    show_data_fake = G_net(z_)
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=5, sharey=True, sharex=True)
    
    for ax, img in zip(axes.flatten(), show_data_fake):
        img = img.detach().cpu().numpy()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        
    if save:
        plt.savefig(path)
    if show:
        plt.show()
    else:
        plt.close()   

    

def show_train_hist(hist, show=False, save=False, path='Train_hist.png'):
    """Loss tracker
    
    Plot the losses of generator and discriminator independently to see the trend
    
    Arguments:
        hist {[dict]} -- Tracking variables
    
    Keyword Arguments:
        show {bool} -- If to display the figure (default: {False})
        save {bool} -- If to store the figure (default: {False})
        path {str} -- path to store the figure (default: {'Train_hist.png'})
    """
    x = range(len(hist['D_losses']))

    y1 = hist['D_losses']
    y2 = hist['G_losses']

    plt.plot(x, y1, label='D_loss')
    plt.plot(x, y2, label='G_loss')

    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.legend(loc=4)
    plt.grid(True)
    plt.tight_layout()

    if save:
        plt.savefig(path)

    if show:
        plt.show()
    else:
        plt.close()


def create_noise(num, dim):
    """Noise constructor
    
    returns a tensor filled with random numbers from a standard normal distribution
    
    Arguments:
        num {int} -- Number of vectors
        dim {int} -- Dimension of vectors
    
    Returns:
        [Tensor] -- the generated noise vector batch
    """
    return torch.randn(num, dim)

# %%
if __name__ == '__main__':
    # initialise the device for training, if gpu is available, device = 'cuda', else: device = 'cpu'
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    data_dir = './MNIST_data/'
    save_dir = './MNIST_GAN_results/'
    image_save_dir = './MNIST_GAN_results/results'

    # create folder if not exist
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    if not os.path.exists(image_save_dir):
        os.mkdir(image_save_dir)

# %%
    # training parameters
    batch_size = 100
    learning_rate = 0.0002
    epochs = 100

    # parameters for Models
    image_size = 28
    G_input_dim = 100
    G_output_dim = image_size * image_size
    D_input_dim = image_size * image_size
    D_output_dim = 1
    hidden_size = 32

# %%
    # construct the dataset and data loader
    transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=(0.5,), std=(0.5,))])
    train_data = datasets.MNIST(root=data_dir, train=True, transform=transform, download=True)
    train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# %%
    # declare the generator and discriminator networks    
    G_net = Generator(G_input_dim, G_output_dim).to(device)
    D_net = Discriminator(D_input_dim, D_output_dim).to(device)

# %%
    # declare the generator and discriminator networks    
    G_net = Generator(G_input_dim, G_output_dim).to(device)
    D_net = Discriminator(D_input_dim, D_output_dim).to(device)

    # Binary Cross Entropy Loss function
    criterion = nn.BCELoss().to(device)

    # Initialise the Optimizers
    G_optimizer = torch.optim.Adam(G_net.parameters(), lr=learning_rate)
    D_optimizer = torch.optim.Adam(D_net.parameters(), lr=learning_rate)

    # tracking variables
    train_hist = {}
    train_hist['D_losses'] = []
    train_hist['G_losses'] = []
    train_hist['per_epoch_ptimes'] = []
    train_hist['total_ptime'] = []

    start_time = time.time()
    # training loop
    for epoch in range(epochs):
        G_net.train()
        D_net.train()
        Loss_G = []
        Loss_D = []
        epoch_start_time = time.time()
        for (image, _) in tqdm(train_loader):
            image = image.to(device)
            b_size = len(image)
            # creat real and fake labels
            real_label = torch.ones(b_size, 1).to(device)
            fake_label = torch.zeros(b_size, 1).to(device)

            # generate fake images 
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))
            data_real = image.view(b_size, D_input_dim)

            # --------train the discriminator network----------
            # compute the loss for real and fake images
            output_real = D_net(data_real)
            output_fake = D_net(data_fake)
            loss_real = criterion(output_real, real_label)
            loss_fake = criterion(output_fake, fake_label)
            loss_d = loss_real + loss_fake

            # back propagation
            D_optimizer.zero_grad()
            loss_d.backward()
            D_optimizer.step()

            # -------- train the generator network-----------
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))

            # compute the loss for generator network
            output_fake = D_net(data_fake)
            loss_g = criterion(output_fake, real_label)

            ## back propagation
            G_optimizer.zero_grad()
            loss_g.backward()
            G_optimizer.step()

            ## store the loss of each iter
            Loss_D.append(loss_d.item())
            Loss_G.append(loss_g.item())

        epoch_loss_g = np.mean(Loss_G)  # mean generator loss for the epoch
        epoch_loss_d = np.mean(Loss_D)  # mean discriminator loss for the epoch
        epoch_end_time = time.time()
        per_epoch_ptime = epoch_end_time - epoch_start_time

        print("Epoch %d of %d with %.2f s" % (epoch + 1, epochs, per_epoch_ptime))
        print("Generator loss: %.8f, Discriminator loss: %.8f" % (epoch_loss_g, epoch_loss_d))

        path = image_save_dir + '/MNIST_GAN_' + str(epoch + 1) + '.png'
        show_result(G_net, create_noise(25, 100).to(device), (epoch + 1), save=True, path=path)
        
        
        if epoch == 9 or epoch == 19 or epoch == 49 or epoch == 99:
            print()
            path1 = generated_images + '/MNIST_GAN_Generated_epoch_images_' + str(epoch+1) + '.png'
            show_generated_images(data_fake , (epoch + 1), save=True, path=path1)
        

        # record the loss for every epoch
        train_hist['G_losses'].append(epoch_loss_g)
        train_hist['D_losses'].append(epoch_loss_d)
        train_hist['per_epoch_ptimes'].append(per_epoch_ptime)

    end_time = time.time()
    total_ptime = end_time - start_time
    train_hist['total_ptime'].append(total_ptime)

    print('Avg per epoch ptime: %.2f, total %d epochs ptime: %.2f' % (
        np.mean(train_hist['per_epoch_ptimes']), epochs, total_ptime))
    print("Training finish!... save training results")
    with open(save_dir + '/train_hist.pkl', 'wb') as f:
        pickle.dump(train_hist, f)
# Out:
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.61it/s]
# Epoch 1 of 100 with 12.60 s
# Generator loss: 3.21128376, Discriminator loss: 0.97637666
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.85it/s]
# Epoch 2 of 100 with 12.28 s
# Generator loss: 3.18282344, Discriminator loss: 0.86139231
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 45.55it/s]
# Epoch 3 of 100 with 13.17 s
# Generator loss: 2.00424475, Discriminator loss: 0.97572930
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.73it/s]
# Epoch 4 of 100 with 12.31 s
# Generator loss: 2.63685737, Discriminator loss: 0.69098991
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.88it/s]
# Epoch 5 of 100 with 12.53 s
# Generator loss: 3.42584683, Discriminator loss: 0.37521676
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 47.22it/s]
# Epoch 6 of 100 with 12.71 s
# Generator loss: 3.40698869, Discriminator loss: 0.41568819
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 45.18it/s]
# Epoch 7 of 100 with 13.28 s
# Generator loss: 3.01806850, Discriminator loss: 0.46289709
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.45it/s]
# Epoch 8 of 100 with 12.38 s
# Generator loss: 2.68621792, Discriminator loss: 0.56064853
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:12<00:00, 48.72it/s]
# Epoch 9 of 100 with 12.32 s
# Generator loss: 2.51895850, Discriminator loss: 0.55630179
# 100%|████████████████████████████████████████████████████████████████████████████████| 600/600 [00:13<00:00, 45.71it/s]
# Epoch 10 of 100 with 13.13 s
# Generator loss: 2.60088823, Discriminator loss: 0.58494737
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-02931105e08b> in <module>
#      79     if epoch == 9 or epoch == 19 or epoch == 49 or epoch == 99:
#      80         print()
# ---> 81         path1 = generated_images + '/MNIST_GAN_Generated_epoch_images_' + str(epoch+1) + '.png'
#      82         show_generated_images(data_fake , (epoch + 1), save=True, path=path1)
#      83
#
# NameError: name 'generated_images' is not defined

# %%
    show_train_hist(train_hist, save=True, path=save_dir + '/MNIST_GAN_train_hist.png')

# %% [markdown]
# ## 2.2 Dropout removed

# %%
class Generator(nn.Module):
    """Image generator
    
    Takes a noise vector as input and syntheses a single channel image accordingly
    """

    def __init__(self, input_dims, output_dims):
        """Init function
        
        Declare the network structure as indicated in CW2 Guidance
        
        Arguments:
            input_dims {int} -- Dimension of input noise vector
            output_dims {int} -- Dimension of the output vector (flatten image)
        """
        super(Generator, self).__init__()
        ###  TODO: Change the architecture and value as CW2 Guidance required
 
        self.fc1 = nn.Sequential(
            nn.Linear(100, 256), 
            nn.LeakyReLU(0.2)
        )
        
        self.fc2 = nn.Sequential(
            nn.Linear(256, 512), 
            nn.LeakyReLU(0.2)
        )
        
        self.fc3 = nn.Sequential(
            nn.Linear(512, 1024), 
            nn.LeakyReLU(0.2)
        )  
        
        # output hidden layer
        self.fc4 = nn.Sequential(
            nn.Linear(1024, output_dims), 
            nn.Tanh()
        )

    def forward(self, x):
        """Forward function
        
        Arguments:
            x {Tensor} -- a batch of noise vectors in shape (<batch_size>x<input_dims>)
        
        Returns:
            Tensor -- a batch of flatten image in shape (<batch_size>x<output_dims>)
        """
        ###  TODO: modify to be consistent with the network structure
        
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x


class Discriminator(nn.Module):
    """Image discriminator
    
    Takes a image as input and predict if it is real from the dataset or fake synthesised by the generator
    """

    def __init__(self, input_dims, output_dims=1):
        """Init function
        
        Declare the discriminator network structure as indicated in CW2 Guidance
        
        Arguments:
            input_dims {int} -- Dimension of the flatten input images
        
        Keyword Arguments:
            output_dims {int} -- Predicted probability (default: {1})
        """
        super(Discriminator, self).__init__()

        ###  TODO: Change the architecture and value as CW2 Guidance required
        
        self.fc1 = nn.Sequential(
            nn.Linear(784, 1024),
            nn.LeakyReLU(0.2)
        )
        
        self.fc2 = nn.Sequential(
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2)
        )
        
        self.fc3 = nn.Sequential(
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2)
        )
        
        self.fc4 = nn.Sequential(
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        """Forward function
        
        Arguments:
            x {Tensor} -- a batch of 2D image in shape (<batch_size>xHxW)
        
        Returns:
            Tensor -- predicted probabilities (<batch_size>)
        """
        ###  TODO: modify to be consistent with the network structure
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)

        return x

# %%
def show_result(G_net, z_, num_epoch, show=False, save=False, path='result.png'):
    """Result visualisation
    
    Show and save the generated figures in the grid fashion
    
    Arguments:
        G_net {[nn.Module]} -- The generator instant
        z_ {[Tensor]} -- Input noise vectors
        num_epoch {[int]} -- Indicate how many epoch has the generator been trained
    
    Keyword Arguments:
        show {bool} -- If to display the images (default: {False})
        save {bool} -- If to store the images (default: {False})
        path {str} -- path to store the images (default: {'result.png'})
    """

    ###  TODO: complete the rest of part
    # hint: use plt.subplots to construct grid
    # hint: use plt.imshow and plt.savefig to display and store the images
    
    show_data_fake = G_net(z_)
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=5, sharey=True, sharex=True)
    
    for ax, img in zip(axes.flatten(), show_data_fake):
        img = img.detach().cpu().numpy()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        
    if save:
        plt.savefig(path)
    if show:
        plt.show()
    else:
        plt.close()   


    

def show_train_hist(hist, show=False, save=False, path='Train_hist.png'):
    """Loss tracker
    
    Plot the losses of generator and discriminator independently to see the trend
    
    Arguments:
        hist {[dict]} -- Tracking variables
    
    Keyword Arguments:
        show {bool} -- If to display the figure (default: {False})
        save {bool} -- If to store the figure (default: {False})
        path {str} -- path to store the figure (default: {'Train_hist.png'})
    """
    x = range(len(hist['D_losses']))

    y1 = hist['D_losses']
    y2 = hist['G_losses']

    plt.plot(x, y1, label='D_loss')
    plt.plot(x, y2, label='G_loss')

    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.legend(loc=4)
    plt.grid(True)
    plt.tight_layout()

    if save:
        plt.savefig(path)

    if show:
        plt.show()
    else:
        plt.close()


def create_noise(num, dim):
    """Noise constructor
    
    returns a tensor filled with random numbers from a standard normal distribution
    
    Arguments:
        num {int} -- Number of vectors
        dim {int} -- Dimension of vectors
    
    Returns:
        [Tensor] -- the generated noise vector batch
    """
    return torch.randn(num, dim)

# %%
if __name__ == '__main__':
    # initialise the device for training, if gpu is available, device = 'cuda', else: device = 'cpu'
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    data_dir = './MNIST_data/'
    save_dir = './MNIST_GAN_results/'
    image_save_dir = './MNIST_GAN_results/results'

    # create folder if not exist
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    if not os.path.exists(image_save_dir):
        os.mkdir(image_save_dir)
    if not os.path.exists(generated_images):
        os.mkdir(generated_images)

# %%
    # training parameters
    batch_size = 100
    learning_rate = 0.0002
    epochs = 100

    # parameters for Models
    image_size = 28
    G_input_dim = 100
    G_output_dim = image_size * image_size
    D_input_dim = image_size * image_size
    D_output_dim = 1
    hidden_size = 32

# %%
    # construct the dataset and data loader
    transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=(0.5,), std=(0.5,))])
    train_data = datasets.MNIST(root=data_dir, train=True, transform=transform, download=True)
    train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# %%
    # declare the generator and discriminator networks    
    G_net = Generator(G_input_dim, G_output_dim).to(device)
    D_net = Discriminator(D_input_dim, D_output_dim).to(device)

# %%
    # declare the generator and discriminator networks    
    G_net = Generator(G_input_dim, G_output_dim).to(device)
    D_net = Discriminator(D_input_dim, D_output_dim).to(device)

    # Binary Cross Entropy Loss function
    criterion = nn.BCELoss().to(device)

    # Initialise the Optimizers
    G_optimizer = torch.optim.Adam(G_net.parameters(), lr=learning_rate)
    D_optimizer = torch.optim.Adam(D_net.parameters(), lr=learning_rate)

    # tracking variables
    train_hist = {}
    train_hist['D_losses'] = []
    train_hist['G_losses'] = []
    train_hist['per_epoch_ptimes'] = []
    train_hist['total_ptime'] = []

    start_time = time.time()
    # training loop
    for epoch in range(epochs):
        G_net.train()
        D_net.train()
        Loss_G = []
        Loss_D = []
        epoch_start_time = time.time()
        for (image, _) in tqdm(train_loader):
            image = image.to(device)
            b_size = len(image)
            # creat real and fake labels
            real_label = torch.ones(b_size, 1).to(device)
            fake_label = torch.zeros(b_size, 1).to(device)

            # generate fake images 
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))
            data_real = image.view(b_size, D_input_dim)

            # --------train the discriminator network----------
            # compute the loss for real and fake images
            output_real = D_net(data_real)
            output_fake = D_net(data_fake)
            loss_real = criterion(output_real, real_label)
            loss_fake = criterion(output_fake, fake_label)
            loss_d = loss_real + loss_fake

            # back propagation
            D_optimizer.zero_grad()
            loss_d.backward()
            D_optimizer.step()

            # -------- train the generator network-----------
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))

            # compute the loss for generator network
            output_fake = D_net(data_fake)
            loss_g = criterion(output_fake, real_label)

            ## back propagation
            G_optimizer.zero_grad()
            loss_g.backward()
            G_optimizer.step()

            ## store the loss of each iter
            Loss_D.append(loss_d.item())
            Loss_G.append(loss_g.item())

        epoch_loss_g = np.mean(Loss_G)  # mean generator loss for the epoch
        epoch_loss_d = np.mean(Loss_D)  # mean discriminator loss for the epoch
        epoch_end_time = time.time()
        per_epoch_ptime = epoch_end_time - epoch_start_time

        print("Epoch %d of %d with %.2f s" % (epoch + 1, epochs, per_epoch_ptime))
        print("Generator loss: %.8f, Discriminator loss: %.8f" % (epoch_loss_g, epoch_loss_d))

        path = image_save_dir + '/MNIST_GAN_' + str(epoch + 1) + '.png'
        show_result(G_net, create_noise(25, 100).to(device), (epoch + 1), save=True, path=path)
        
        
        if epoch == 9 or epoch == 19 or epoch == 49 or epoch == 99:
            path1 = generated_images + '/MNIST_GAN_Generated_epoch_images_' + str(epoch+1) + '.png'
            show_generated_images(data_fake , (epoch + 1), save=True, path=path1)
        

        # record the loss for every epoch
        train_hist['G_losses'].append(epoch_loss_g)
        train_hist['D_losses'].append(epoch_loss_d)
        train_hist['per_epoch_ptimes'].append(per_epoch_ptime)

    end_time = time.time()
    total_ptime = end_time - start_time
    train_hist['total_ptime'].append(total_ptime)

    print('Avg per epoch ptime: %.2f, total %d epochs ptime: %.2f' % (
        np.mean(train_hist['per_epoch_ptimes']), epochs, total_ptime))
    print("Training finish!... save training results")
    with open(save_dir + '/train_hist.pkl', 'wb') as f:
        pickle.dump(train_hist, f)
    show_train_hist(train_hist, save=True, path=save_dir + '/MNIST_GAN_train_hist.png')

# %%
    end_time = time.time()
    total_ptime = end_time - start_time
    train_hist['total_ptime'].append(total_ptime)

    print('Avg per epoch ptime: %.2f, total %d epochs ptime: %.2f' % (
        np.mean(train_hist['per_epoch_ptimes']), epochs, total_ptime))
    print("Training finish!... save training results")
    with open(save_dir + '/train_hist.pkl', 'wb') as f:
        pickle.dump(train_hist, f)

# %%
    show_train_hist(train_hist, save=True, path=save_dir + '/MNIST_GAN_train_hist_no_dropout.png')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread(save_dir + 'MNIST_GAN_train_hist_no_dropout.png'))

# %% [markdown]
# ## 2.3. save generated images

# %%
import os
import pickle
import time

import matplotlib.pyplot as plt
import numpy as np
import torch
import torch.nn as nn
import torchvision.datasets as datasets
import torchvision.transforms as transforms
from torch.utils.data import DataLoader
from tqdm import tqdm

# %%
class Generator(nn.Module):
    """Image generator
    
    Takes a noise vector as input and syntheses a single channel image accordingly
    """

    def __init__(self, input_dims, output_dims):
        """Init function
        
        Declare the network structure as indicated in CW2 Guidance
        
        Arguments:
            input_dims {int} -- Dimension of input noise vector
            output_dims {int} -- Dimension of the output vector (flatten image)
        """
        super(Generator, self).__init__()
        ###  TODO: Change the architecture and value as CW2 Guidance required
        
        self.fc1 = nn.Sequential(
            nn.Linear(100, 256), 
            nn.LeakyReLU(0.2)
        )
        
        self.fc2 = nn.Sequential(
            nn.Linear(256, 512), 
            nn.LeakyReLU(0.2)
        )
        
        self.fc3 = nn.Sequential(
            nn.Linear(512, 1024), 
            nn.LeakyReLU(0.2)
        )  
        
        # output hidden layer
        self.fc4 = nn.Sequential(
            nn.Linear(1024, output_dims), 
            nn.Tanh()
        )

    def forward(self, x):
        """Forward function
        
        Arguments:
            x {Tensor} -- a batch of noise vectors in shape (<batch_size>x<input_dims>)
        
        Returns:
            Tensor -- a batch of flatten image in shape (<batch_size>x<output_dims>)
        """
        ###  TODO: modify to be consistent with the network structure
        
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)
        return x


class Discriminator(nn.Module):
    """Image discriminator
    
    Takes a image as input and predict if it is real from the dataset or fake synthesised by the generator
    """

    def __init__(self, input_dims, output_dims=1):
        """Init function
        
        Declare the discriminator network structure as indicated in CW2 Guidance
        
        Arguments:
            input_dims {int} -- Dimension of the flatten input images
        
        Keyword Arguments:
            output_dims {int} -- Predicted probability (default: {1})
        """
        super(Discriminator, self).__init__()

        ###  TODO: Change the architecture and value as CW2 Guidance required

        self.fc1 = nn.Sequential(
            nn.Linear(784, 1024),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        
        self.fc2 = nn.Sequential(
            nn.Linear(1024, 512),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        
        self.fc3 = nn.Sequential(
            nn.Linear(512, 256),
            nn.LeakyReLU(0.2),
            nn.Dropout(0.3)
        )
        
        self.fc4 = nn.Sequential(
            nn.Linear(256, 1),
            nn.Sigmoid()
        )

    def forward(self, x):
        """Forward function
        
        Arguments:
            x {Tensor} -- a batch of 2D image in shape (<batch_size>xHxW)
        
        Returns:
            Tensor -- predicted probabilities (<batch_size>)
        """
        ###  TODO: modify to be consistent with the network structure
        
        x = self.fc1(x)
        x = self.fc2(x)
        x = self.fc3(x)
        x = self.fc4(x)

        return x

# %%
def show_result(G_net, z_, num_epoch, show=False, save=False, path='result.png'):
    """Result visualisation
    
    Show and save the generated figures in the grid fashion
    
    Arguments:
        G_net {[nn.Module]} -- The generator instant
        z_ {[Tensor]} -- Input noise vectors
        num_epoch {[int]} -- Indicate how many epoch has the generator been trained
    
    Keyword Arguments:
        show {bool} -- If to display the images (default: {False})
        save {bool} -- If to store the images (default: {False})
        path {str} -- path to store the images (default: {'result.png'})
    """

    ###  TODO: complete the rest of part
    # hint: use plt.subplots to construct grid
    # hint: use plt.imshow and plt.savefig to display and store the images
    
    show_data_fake = G_net(z_)
    fig, axes = plt.subplots(figsize=(7,7), nrows=5, ncols=5, sharey=True, sharex=True)
    
    for ax, img in zip(axes.flatten(), show_data_fake):
        img = img.detach().cpu().numpy()
        ax.xaxis.set_visible(False)
        ax.yaxis.set_visible(False)
        ax.imshow(img.reshape((28,28)), cmap='Greys_r')
        
    if save:
        plt.savefig(path)
    if show:
        plt.show()
    else:
        plt.close()   


def show_train_hist(hist, show=False, save=False, path='Train_hist.png'):
    """Loss tracker
    
    Plot the losses of generator and discriminator independently to see the trend
    
    Arguments:
        hist {[dict]} -- Tracking variables
    
    Keyword Arguments:
        show {bool} -- If to display the figure (default: {False})
        save {bool} -- If to store the figure (default: {False})
        path {str} -- path to store the figure (default: {'Train_hist.png'})
    """
    x = range(len(hist['D_losses']))

    y1 = hist['D_losses']
    y2 = hist['G_losses']

    plt.plot(x, y1, label='D_loss')
    plt.plot(x, y2, label='G_loss')

    plt.xlabel('Epoch')
    plt.ylabel('Loss')

    plt.legend(loc=4)
    plt.grid(True)
    plt.tight_layout()

    if save:
        plt.savefig(path)

    if show:
        plt.show()
    else:
        plt.close()


def create_noise(num, dim):
    """Noise constructor
    
    returns a tensor filled with random numbers from a standard normal distribution
    
    Arguments:
        num {int} -- Number of vectors
        dim {int} -- Dimension of vectors
    
    Returns:
        [Tensor] -- the generated noise vector batch
    """
    return torch.randn(num, dim)

# %%
if __name__ == '__main__':
    # initialise the device for training, if gpu is available, device = 'cuda', else: device = 'cpu'
    device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    data_dir = './MNIST_data/'
    save_dir = './MNIST_GAN_results/'
    image_save_dir = './MNIST_GAN_results/results'
    generated_images = './MNIST_GAN_results/generated images'

    # create folder if not exist
    if not os.path.exists(save_dir):
        os.mkdir(save_dir)
    if not os.path.exists(image_save_dir):
        os.mkdir(image_save_dir)
    if not os.path.exists(generated_images):
        os.mkdir(generated_images)

# %%
    # training parameters
    batch_size = 100
    learning_rate = 0.0002
    epochs = 100

    # parameters for Models
    image_size = 28
    G_input_dim = 100
    G_output_dim = image_size * image_size
    D_input_dim = image_size * image_size
    D_output_dim = 1
    hidden_size = 32

# %%
    # construct the dataset and data loader
    transform = transforms.Compose([transforms.ToTensor(),transforms.Normalize(mean=(0.5,), std=(0.5,))])
    train_data = datasets.MNIST(root=data_dir, train=True, transform=transform, download=True)
    train_loader = DataLoader(dataset=train_data, batch_size=batch_size, shuffle=True)

# %%
    # declare the generator and discriminator networks    
    G_net = Generator(G_input_dim, G_output_dim).to(device)
    D_net = Discriminator(D_input_dim, D_output_dim).to(device)

    # Binary Cross Entropy Loss function
    criterion = nn.BCELoss().to(device)

    # Initialise the Optimizers
    G_optimizer = torch.optim.Adam(G_net.parameters(), lr=learning_rate)
    D_optimizer = torch.optim.Adam(D_net.parameters(), lr=learning_rate)

    # tracking variables
    train_hist = {}
    train_hist['D_losses'] = []
    train_hist['G_losses'] = []
    train_hist['per_epoch_ptimes'] = []
    train_hist['total_ptime'] = []

    start_time = time.time()
    # training loop
    for epoch in range(epochs):
        G_net.train()
        D_net.train()
        Loss_G = []
        Loss_D = []
        epoch_start_time = time.time()
        for (image, _) in tqdm(train_loader):
            image = image.to(device)
            b_size = len(image)
            # creat real and fake labels
            real_label = torch.ones(b_size, 1).to(device)
            fake_label = torch.zeros(b_size, 1).to(device)

            # generate fake images 
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))
            data_real = image.view(b_size, D_input_dim)

            # --------train the discriminator network----------
            # compute the loss for real and fake images
            output_real = D_net(data_real)
            output_fake = D_net(data_fake)
            loss_real = criterion(output_real, real_label)
            loss_fake = criterion(output_fake, fake_label)
            loss_d = loss_real + loss_fake

            # back propagation
            D_optimizer.zero_grad()
            loss_d.backward()
            D_optimizer.step()

            # -------- train the generator network-----------
            data_fake = G_net(create_noise(b_size, G_input_dim).to(device))

            # compute the loss for generator network
            output_fake = D_net(data_fake)
            loss_g = criterion(output_fake, real_label)

            ## back propagation
            G_optimizer.zero_grad()
            loss_g.backward()
            G_optimizer.step()

            ## store the loss of each iter
            Loss_D.append(loss_d.item())
            Loss_G.append(loss_g.item())

        epoch_loss_g = np.mean(Loss_G)  # mean generator loss for the epoch
        epoch_loss_d = np.mean(Loss_D)  # mean discriminator loss for the epoch
        epoch_end_time = time.time()
        per_epoch_ptime = epoch_end_time - epoch_start_time

        print("Epoch %d of %d with %.2f s" % (epoch + 1, epochs, per_epoch_ptime))
        print("Generator loss: %.8f, Discriminator loss: %.8f" % (epoch_loss_g, epoch_loss_d))

        #show opoch  10, 20, 50, and 100      
        if epoch == 9 or epoch == 19 or epoch == 49 or epoch == 99:
            path = image_save_dir + '/MNIST_GAN_' + str(epoch + 1) + '.png'
            show_result(G_net, create_noise(25, 100).to(device), (epoch + 1), save=True, path=path)

        # record the loss for every epoch
        train_hist['G_losses'].append(epoch_loss_g)
        train_hist['D_losses'].append(epoch_loss_d)
        train_hist['per_epoch_ptimes'].append(per_epoch_ptime)

    end_time = time.time()
    total_ptime = end_time - start_time
    train_hist['total_ptime'].append(total_ptime)

    print('Avg per epoch ptime: %.2f, total %d epochs ptime: %.2f' % (
        np.mean(train_hist['per_epoch_ptimes']), epochs, total_ptime))
    print("Training finish!... save training results")
    with open(save_dir + '/train_hist.pkl', 'wb') as f:
        pickle.dump(train_hist, f)

# %%
    show_train_hist(train_hist, save=True, path=save_dir + '/MNIST_GAN_train_hist.png')

# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
plt.imshow(mpimg.imread(save_dir + 'MNIST_GAN_train_hist_no_dropout.png'))

# %%
plt.imshow(mpimg.imread(image_save_dir + '/MNIST_GAN_10.png'))

# %%
plt.imshow(mpimg.imread(image_save_dir + '/MNIST_GAN_20.png'))

# %%
plt.imshow(mpimg.imread(image_save_dir + '/MNIST_GAN_50.png'))

# %%
plt.imshow(mpimg.imread(image_save_dir + '/MNIST_GAN_100.png'))
